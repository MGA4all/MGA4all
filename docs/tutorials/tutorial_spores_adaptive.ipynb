# %% [markdown]
# # Tutorial: Adaptive-SPORES x PyPSA

# %%
import yaml
import pypsa

from mga4all.examples import create_pypsa_network

import pandas as pd

# %% [markdown]
# ## 1. Load example PyPSA model

# %%
# Load example PyPSA model that the config refers to
n = create_pypsa_network()
# Out:
# INFO:pypsa.network.io:Imported network 'SciGrid-DE' has buses, carriers, generators, lines, loads, storage_units, transformers

# %%
# Set the desired solver options
pypsa.options.params.optimize.solver_name = "gurobi"
pypsa.options.params.optimize.solver_options = {
    'Method': 2,  # Use the barrier algorithm
    'Crossover': 0,
}

# %%
# Find cost-optimal solution
n.optimize(log_to_console=False);
# Out:
# /tmp/ipykernel_115023/2238090962.py:2: FutureWarning: The default value of `include_objective_constant` will change from True to False in version 2.0. Set `include_objective_constant` explicitly to suppress this warning. Using False improves LP numerical conditioning by not including the objective constant as a variable.
#   n.optimize(log_to_console=False);
# WARNING:pypsa.consistency:The following lines have zero x, which could break the linear load flow:
# Index(['line'], dtype='object', name='name')
# WARNING:pypsa.consistency:The following lines have zero r, which could break the linear load flow:
# Index(['line'], dtype='object', name='name')
# INFO:linopy.model: Solve problem using Gurobi solver
# INFO:linopy.model:Solver options:
#  - Method: 2
#  - Crossover: 0
#  - log_to_console: False
# INFO:linopy.io: Writing time: 0.06s
# Set parameter Username
# INFO:gurobipy:Set parameter Username
# Academic license - for non-commercial use only - expires 2026-08-25
# INFO:gurobipy:Academic license - for non-commercial use only - expires 2026-08-25
# Read LP format model from file /tmp/linopy-problem-9kgjymdg.lp
# INFO:gurobipy:Read LP format model from file /tmp/linopy-problem-9kgjymdg.lp
# Reading time = 0.00 seconds
# INFO:gurobipy:Reading time = 0.00 seconds
# obj: 688 rows, 296 columns, 1324 nonzeros
# INFO:gurobipy:obj: 688 rows, 296 columns, 1324 nonzeros
# Set parameter Method to value 2
# INFO:gurobipy:Set parameter Method to value 2
# Set parameter Crossover to value 0
# INFO:gurobipy:Set parameter Crossover to value 0
# Set parameter LogToConsole to value 0
# INFO:gurobipy:Set parameter LogToConsole to value 0
# INFO:gurobipy:Gurobi Optimizer version 12.0.3 build v12.0.3rc0 (linux64 - "Linux Mint 22")
# INFO:gurobipy:
# INFO:gurobipy:CPU model: Intel(R) Core(TM) i7-10610U CPU @ 1.80GHz, instruction set [SSE2|AVX|AVX2]
# INFO:gurobipy:Thread count: 4 physical cores, 8 logical processors, using up to 8 threads
# INFO:gurobipy:
# INFO:gurobipy:Non-default parameters:
# INFO:gurobipy:Method  2
# INFO:gurobipy:Crossover  0
# INFO:gurobipy:LogToConsole  0
# INFO:gurobipy:
# INFO:gurobipy:Optimize a model with 688 rows, 296 columns and 1324 nonzeros
# INFO:gurobipy:Model fingerprint: 0xd41ae2e6
# INFO:gurobipy:Coefficient statistics:
# INFO:gurobipy:  Matrix range     [4e-02, 5e+00]
# INFO:gurobipy:  Objective range  [4e+02, 2e+03]
# INFO:gurobipy:  Bounds range     [0e+00, 0e+00]
# INFO:gurobipy:  RHS range        [2e+02, 1e+03]
# INFO:gurobipy:Presolve removed 124 rows and 332 columns
# INFO:gurobipy:Presolve time: 0.00s
# INFO:gurobipy:Presolved: 172 rows, 356 columns, 1572 nonzeros
# INFO:gurobipy:Ordering time: 0.00s
# INFO:gurobipy:
# INFO:gurobipy:Barrier statistics:
# INFO:gurobipy: Free vars  : 6
# INFO:gurobipy: AA' NZ     : 1.462e+03
# INFO:gurobipy: Factor NZ  : 3.702e+03
# INFO:gurobipy: Factor Ops : 8.857e+04 (less than 1 second per iteration)
# INFO:gurobipy: Threads    : 1
# INFO:gurobipy:
# INFO:gurobipy:                  Objective                Residual
# INFO:gurobipy:Iter       Primal          Dual         Primal    Dual     Compl     Time
# INFO:gurobipy:   0  -1.00409619e+07  1.26434985e+06  5.02e+04 2.32e+02  8.08e+05     0s
# INFO:gurobipy:   1  -1.62363797e+07  3.83761269e+06  1.05e+04 1.29e+02  2.23e+05     0s
# INFO:gurobipy:   2  -1.19102174e+07  3.48788782e+06  3.62e+02 2.51e-04  3.20e+04     0s
# INFO:gurobipy:   3  -2.57093358e+06  1.77942311e+06  9.73e+01 3.18e-04  8.90e+03     0s
# INFO:gurobipy:   4  -2.27818582e+04  1.28001349e+06  1.28e+01 1.34e-04  2.59e+03     0s
# INFO:gurobipy:   5   2.15322037e+05  1.03328648e+06  8.76e+00 6.29e-05  1.62e+03     0s
# INFO:gurobipy:   6  -1.20186200e+05  8.65093190e+05  2.34e+00 5.33e-05  1.92e+03     0s
# INFO:gurobipy:   7   4.63414619e+05  7.17305096e+05  3.85e-01 2.15e-05  4.94e+02     0s
# INFO:gurobipy:   8   5.78794372e+05  6.53916444e+05  8.15e-02 1.62e-05  1.46e+02     0s
# INFO:gurobipy:   9   6.03297884e+05  6.24674068e+05  2.14e-02 7.14e-06  4.15e+01     0s
# INFO:gurobipy:  10   6.14810979e+05  6.19552578e+05  8.25e-04 8.53e-05  9.21e+00     0s
# INFO:gurobipy:  11   6.15517016e+05  6.15556729e+05  6.88e-07 4.45e-06  7.71e-02     0s
# INFO:gurobipy:  12   6.15519375e+05  6.15519415e+05  4.71e-09 4.03e-08  7.71e-05     0s
# INFO:gurobipy:  13   6.15519377e+05  6.15519377e+05  2.43e-09 3.58e-11  2.54e-10     0s
# INFO:gurobipy:
# INFO:gurobipy:Barrier solved model in 13 iterations and 0.02 seconds (0.00 work units)
# INFO:gurobipy:Optimal objective 6.15519377e+05
# INFO:gurobipy:
# INFO:linopy.constants: Optimization successful:
# Status: ok
# Termination condition: optimal
# Solution: 296 primals, 688 duals
# Objective: 6.16e+05
# Solver: gurobi
# Runtime: 0.02s
# Dual bound: 6.16e+05
# Solver model: available
# Solver message: 2
#
# INFO:pypsa.optimization.optimize:The shadow-prices of the constraints Generator-ext-p-lower, Generator-ext-p-upper, Line-ext-s-lower, Line-ext-s-upper, StorageUnit-ext-p_dispatch-lower, StorageUnit-ext-p_dispatch-upper, StorageUnit-ext-p_store-lower, StorageUnit-ext-p_store-upper, StorageUnit-ext-state_of_charge-lower, StorageUnit-ext-state_of_charge-upper, StorageUnit-energy_balance were not assigned to the network.

# %% [markdown]
# ## 2. Generate alternative solutions with SPORES MGA (simple diversificaton)

# %% [markdown]
# ### 2.1 Load and check MGA configuration

# %%
from mga4all.validate import SPORESConfig

# Load configuration file
with open("../../configs/test_config_spores_diversify_only.yaml") as yf:
    test_config = SPORESConfig.model_validate(yaml.safe_load(yf))

# %%
# Check that it reflects the desired setup
test_config
# Out:
# {'config_name': 'spores',
#  'model_interface': 'pypsa',
#  'cost_slack': 0.2,
#  'alternatives': 5,
#  'spatially_explicit': True,
#  'diversification_coefficient': 'auto',
#  'intensification_coefficient': 0,
#  'diversified_technologies': ['wind', 'solar', 'gas', 'battery'],
#  'intensified_technologies': []}

# %% [markdown]
# ### 2.2 Import algorithm and run

# %%
from mga4all.mga_spores import spores_algorithm_adaptive

# %%
mga_alternatives, mga_spatial_alternatives, mga_weights = spores_algorithm_adaptive(test_config, n)
# Out:
# WARNING:pypsa.consistency:Encountered nan's in varying data 'v_ang' for columns ['bus1', 'bus2'] of component 'Bus'.
# WARNING:pypsa.consistency:The following lines have zero x, which could break the linear load flow:
# Index(['line'], dtype='object', name='name')
# WARNING:pypsa.consistency:The following lines have zero r, which could break the linear load flow:
# Index(['line'], dtype='object', name='name')
# INFO:linopy.model: Solve problem using Gurobi solver
# INFO:linopy.model:Solver options:
#  - Method: 2
#  - Crossover: 0
#  - log_to_console: False
# INFO:linopy.io: Writing time: 0.05s
# Technologies [] not found in the model
# Set parameter Username
# INFO:gurobipy:Set parameter Username
# Academic license - for non-commercial use only - expires 2026-08-25
# INFO:gurobipy:Academic license - for non-commercial use only - expires 2026-08-25
# Read LP format model from file /tmp/linopy-problem-g9hx4k64.lp
# INFO:gurobipy:Read LP format model from file /tmp/linopy-problem-g9hx4k64.lp
# Reading time = 0.00 seconds
# INFO:gurobipy:Reading time = 0.00 seconds
# obj: 689 rows, 296 columns, 1332 nonzeros
# INFO:gurobipy:obj: 689 rows, 296 columns, 1332 nonzeros
# Set parameter Method to value 2
# INFO:gurobipy:Set parameter Method to value 2
# Set parameter Crossover to value 0
# INFO:gurobipy:Set parameter Crossover to value 0
# Set parameter LogToConsole to value 0
# INFO:gurobipy:Set parameter LogToConsole to value 0
# INFO:gurobipy:Gurobi Optimizer version 12.0.3 build v12.0.3rc0 (linux64 - "Linux Mint 22")
# INFO:gurobipy:
# INFO:gurobipy:CPU model: Intel(R) Core(TM) i7-10610U CPU @ 1.80GHz, instruction set [SSE2|AVX|AVX2]
# INFO:gurobipy:Thread count: 4 physical cores, 8 logical processors, using up to 8 threads
# INFO:gurobipy:
# INFO:gurobipy:Non-default parameters:
# INFO:gurobipy:Method  2
# INFO:gurobipy:Crossover  0
# INFO:gurobipy:LogToConsole  0
# INFO:gurobipy:
# INFO:gurobipy:Optimize a model with 689 rows, 296 columns and 1332 nonzeros
# INFO:gurobipy:Model fingerprint: 0x90609b26
# INFO:gurobipy:Coefficient statistics:
# INFO:gurobipy:  Matrix range     [4e-02, 2e+03]
# INFO:gurobipy:  Objective range  [4e-15, 9e-01]
# INFO:gurobipy:  Bounds range     [0e+00, 0e+00]
# INFO:gurobipy:  RHS range        [2e+02, 7e+05]
# INFO:gurobipy:Presolve removed 124 rows and 334 columns
# INFO:gurobipy:Presolve time: 0.00s
# INFO:gurobipy:Presolved: 172 rows, 355 columns, 1578 nonzeros
# INFO:gurobipy:Ordering time: 0.00s
# INFO:gurobipy:
# INFO:gurobipy:Barrier statistics:
# INFO:gurobipy: Free vars  : 6
# INFO:gurobipy: AA' NZ     : 1.490e+03
# INFO:gurobipy: Factor NZ  : 3.248e+03
# INFO:gurobipy: Factor Ops : 6.994e+04 (less than 1 second per iteration)
# INFO:gurobipy: Threads    : 1
# INFO:gurobipy:
# INFO:gurobipy:                  Objective                Residual
# INFO:gurobipy:Iter       Primal          Dual         Primal    Dual     Compl     Time
# INFO:gurobipy:   0  -1.00089303e+04 -0.00000000e+00  1.16e+00 2.28e+02  4.08e+02     0s
# INFO:gurobipy:   1  -9.54900421e+03 -1.69009538e+03  4.93e-01 7.12e+02  1.14e+02     0s
# INFO:gurobipy:   2  -4.51532485e+03 -3.28851583e+02  2.93e-02 2.09e+02  3.14e+01     0s
# INFO:gurobipy:   3  -1.02547240e+03  9.74314439e+01  1.49e-03 2.78e+01  4.66e+00     0s
# INFO:gurobipy:   4  -3.12245995e+02  3.52838830e+01  4.71e-05 3.01e+00  8.82e-01     0s
# INFO:gurobipy:   5  -1.12760202e+02  2.77082751e+01  1.58e-05 1.09e+00  3.30e-01     0s
# INFO:gurobipy:   6  -2.16118808e+01  1.97717561e+01  3.71e-06 2.89e-01  8.77e-02     0s
# INFO:gurobipy:   7   2.89580855e-02  1.22624370e+01  5.76e-07 5.19e-02  2.52e-02     0s
# INFO:gurobipy:   8   4.62229408e+00  7.50552358e+00  1.12e-07 5.80e-03  5.90e-03     0s
# INFO:gurobipy:   9   5.75730867e+00  6.62299648e+00  2.48e-08 4.18e-03  1.80e-03     0s
# INFO:gurobipy:  10   6.09087738e+00  6.15588426e+00  5.72e-09 1.95e-04  1.31e-04     0s
# INFO:gurobipy:  11   6.09890825e+00  6.09926944e+00  7.28e-10 1.46e-10  7.14e-07     0s
# INFO:gurobipy:  12   6.09900645e+00  6.09900689e+00  1.82e-11 1.82e-12  8.44e-10     0s
# INFO:gurobipy:  13   6.09900662e+00  6.09900663e+00  2.51e-14 1.82e-12  8.44e-13     0s
# INFO:gurobipy:
# INFO:gurobipy:Barrier solved model in 13 iterations and 0.01 seconds (0.00 work units)
# INFO:gurobipy:Optimal objective 6.09900662e+00
# INFO:gurobipy:
# INFO:linopy.constants: Optimization successful:
# Status: ok
# Termination condition: optimal
# Solution: 296 primals, 689 duals
# Objective: 6.10e+00
# Solver: gurobi
# Runtime: 0.01s
# Dual bound: 6.10e+00
# Solver model: available
# Solver message: 2
#
# INFO:pypsa.optimization.optimize:The shadow-prices of the constraints Generator-ext-p-lower, Generator-ext-p-upper, Line-ext-s-lower, Line-ext-s-upper, StorageUnit-ext-p_dispatch-lower, StorageUnit-ext-p_dispatch-upper, StorageUnit-ext-p_store-lower, StorageUnit-ext-p_store-upper, StorageUnit-ext-state_of_charge-lower, StorageUnit-ext-state_of_charge-upper, StorageUnit-energy_balance, budget were not assigned to the network.
# INFO:linopy.model: Solve problem using Gurobi solver
# INFO:linopy.model:Solver options:
#  - Method: 2
#  - Crossover: 0
#  - log_to_console: False
# INFO:linopy.io: Writing time: 0.06s
# Set parameter Username
# INFO:gurobipy:Set parameter Username
# Academic license - for non-commercial use only - expires 2026-08-25
# INFO:gurobipy:Academic license - for non-commercial use only - expires 2026-08-25
# Read LP format model from file /tmp/linopy-problem-n1wkcocg.lp
# INFO:gurobipy:Read LP format model from file /tmp/linopy-problem-n1wkcocg.lp
# Reading time = 0.00 seconds
# INFO:gurobipy:Reading time = 0.00 seconds
# obj: 689 rows, 296 columns, 1332 nonzeros
# INFO:gurobipy:obj: 689 rows, 296 columns, 1332 nonzeros
# Set parameter Method to value 2
# INFO:gurobipy:Set parameter Method to value 2
# Set parameter Crossover to value 0
# INFO:gurobipy:Set parameter Crossover to value 0
# Set parameter LogToConsole to value 0
# INFO:gurobipy:Set parameter LogToConsole to value 0
# INFO:gurobipy:Gurobi Optimizer version 12.0.3 build v12.0.3rc0 (linux64 - "Linux Mint 22")
# INFO:gurobipy:
# INFO:gurobipy:CPU model: Intel(R) Core(TM) i7-10610U CPU @ 1.80GHz, instruction set [SSE2|AVX|AVX2]
# INFO:gurobipy:Thread count: 4 physical cores, 8 logical processors, using up to 8 threads
# INFO:gurobipy:
# INFO:gurobipy:Non-default parameters:
# INFO:gurobipy:Method  2
# INFO:gurobipy:Crossover  0
# INFO:gurobipy:LogToConsole  0
# INFO:gurobipy:
# INFO:gurobipy:Optimize a model with 689 rows, 296 columns and 1332 nonzeros
# INFO:gurobipy:Model fingerprint: 0x6c140cf8
# INFO:gurobipy:Coefficient statistics:
# INFO:gurobipy:  Matrix range     [4e-02, 2e+03]
# INFO:gurobipy:  Objective range  [7e-14, 9e-01]
# INFO:gurobipy:  Bounds range     [0e+00, 0e+00]
# INFO:gurobipy:  RHS range        [2e+02, 7e+05]
# INFO:gurobipy:Presolve removed 124 rows and 334 columns
# INFO:gurobipy:Presolve time: 0.00s
# INFO:gurobipy:Presolved: 172 rows, 355 columns, 1578 nonzeros
# INFO:gurobipy:Ordering time: 0.00s
# INFO:gurobipy:
# INFO:gurobipy:Barrier statistics:
# INFO:gurobipy: Free vars  : 6
# INFO:gurobipy: AA' NZ     : 1.490e+03
# INFO:gurobipy: Factor NZ  : 3.248e+03
# INFO:gurobipy: Factor Ops : 6.994e+04 (less than 1 second per iteration)
# INFO:gurobipy: Threads    : 1
# INFO:gurobipy:
# INFO:gurobipy:                  Objective                Residual
# INFO:gurobipy:Iter       Primal          Dual         Primal    Dual     Compl     Time
# INFO:gurobipy:   0  -9.37124592e+03 -0.00000000e+00  1.08e+00 2.28e+02  3.80e+02     0s
# INFO:gurobipy:   1  -8.95320360e+03 -1.73933501e+03  4.76e-01 6.19e+02  9.70e+01     0s
# INFO:gurobipy:   2  -3.77343265e+03 -2.33617727e+02  1.48e-02 1.88e+02  2.61e+01     0s
# INFO:gurobipy:   3  -9.21456458e+02  7.82335636e+01  5.49e-04 1.90e+01  3.43e+00     0s
# INFO:gurobipy:   4  -2.51483499e+02  6.10053359e+01  4.24e-05 4.37e-01  6.32e-01     0s
# INFO:gurobipy:   5  -4.46202262e+01  3.31940169e+01  1.12e-05 2.58e-03  1.52e-01     0s
# INFO:gurobipy:   6  -2.20893867e+01  1.81104033e+01  5.65e-06 4.93e-08  7.83e-02     0s
# INFO:gurobipy:   7  -2.36764325e+00  3.19129943e+00  2.33e-07 1.30e-08  1.08e-02     0s
# INFO:gurobipy:   8  -2.02728153e-01  4.40743532e-01  1.70e-08 5.07e-09  1.25e-03     0s
# INFO:gurobipy:   9  -1.14293854e-03  1.23084946e-03  1.50e-09 1.70e-10  4.62e-06     0s
# INFO:gurobipy:  10  -1.14229738e-06  1.23165242e-06  5.21e-12 1.82e-12  4.62e-09     0s
# INFO:gurobipy:  11  -2.30832127e-09  1.05503928e-09  2.22e-12 6.82e-13  4.72e-12     0s
# INFO:gurobipy:
# INFO:gurobipy:Barrier solved model in 11 iterations and 0.01 seconds (0.00 work units)
# INFO:gurobipy:Optimal objective -2.30832127e-09
# INFO:gurobipy:
# INFO:linopy.constants: Optimization successful:
# Status: ok
# Termination condition: optimal
# Solution: 296 primals, 689 duals
# Objective: 1.06e-09
# Solver: gurobi
# Runtime: 0.02s
# Dual bound: 1.06e-09
# Solver model: available
# Solver message: 2
#
# INFO:pypsa.optimization.optimize:The shadow-prices of the constraints Generator-ext-p-lower, Generator-ext-p-upper, Line-ext-s-lower, Line-ext-s-upper, StorageUnit-ext-p_dispatch-lower, StorageUnit-ext-p_dispatch-upper, StorageUnit-ext-p_store-lower, StorageUnit-ext-p_store-upper, StorageUnit-ext-state_of_charge-lower, StorageUnit-ext-state_of_charge-upper, StorageUnit-energy_balance, budget were not assigned to the network.
# INFO:linopy.model: Solve problem using Gurobi solver
# INFO:linopy.model:Solver options:
#  - Method: 2
#  - Crossover: 0
#  - log_to_console: False
# INFO:linopy.io: Writing time: 0.06s
# Set parameter Username
# INFO:gurobipy:Set parameter Username
# Academic license - for non-commercial use only - expires 2026-08-25
# INFO:gurobipy:Academic license - for non-commercial use only - expires 2026-08-25
# Read LP format model from file /tmp/linopy-problem-q13rj2gr.lp
# INFO:gurobipy:Read LP format model from file /tmp/linopy-problem-q13rj2gr.lp
# Reading time = 0.00 seconds
# INFO:gurobipy:Reading time = 0.00 seconds
# obj: 689 rows, 296 columns, 1332 nonzeros
# INFO:gurobipy:obj: 689 rows, 296 columns, 1332 nonzeros
# Set parameter Method to value 2
# INFO:gurobipy:Set parameter Method to value 2
# Set parameter Crossover to value 0
# INFO:gurobipy:Set parameter Crossover to value 0
# Set parameter LogToConsole to value 0
# INFO:gurobipy:Set parameter LogToConsole to value 0
# INFO:gurobipy:Gurobi Optimizer version 12.0.3 build v12.0.3rc0 (linux64 - "Linux Mint 22")
# INFO:gurobipy:
# INFO:gurobipy:CPU model: Intel(R) Core(TM) i7-10610U CPU @ 1.80GHz, instruction set [SSE2|AVX|AVX2]
# INFO:gurobipy:Thread count: 4 physical cores, 8 logical processors, using up to 8 threads
# INFO:gurobipy:
# INFO:gurobipy:Non-default parameters:
# INFO:gurobipy:Method  2
# INFO:gurobipy:Crossover  0
# INFO:gurobipy:LogToConsole  0
# INFO:gurobipy:
# INFO:gurobipy:Optimize a model with 689 rows, 296 columns and 1332 nonzeros
# INFO:gurobipy:Model fingerprint: 0x0706c466
# INFO:gurobipy:Coefficient statistics:
# INFO:gurobipy:  Matrix range     [4e-02, 2e+03]
# INFO:gurobipy:  Objective range  [9e-02, 9e-01]
# INFO:gurobipy:  Bounds range     [0e+00, 0e+00]
# INFO:gurobipy:  RHS range        [2e+02, 7e+05]
# INFO:gurobipy:Presolve removed 124 rows and 334 columns
# INFO:gurobipy:Presolve time: 0.00s
# INFO:gurobipy:Presolved: 172 rows, 355 columns, 1578 nonzeros
# INFO:gurobipy:Ordering time: 0.00s
# INFO:gurobipy:
# INFO:gurobipy:Barrier statistics:
# INFO:gurobipy: Free vars  : 6
# INFO:gurobipy: AA' NZ     : 1.490e+03
# INFO:gurobipy: Factor NZ  : 3.248e+03
# INFO:gurobipy: Factor Ops : 6.994e+04 (less than 1 second per iteration)
# INFO:gurobipy: Threads    : 1
# INFO:gurobipy:
# INFO:gurobipy:                  Objective                Residual
# INFO:gurobipy:Iter       Primal          Dual         Primal    Dual     Compl     Time
# INFO:gurobipy:   0  -8.92427499e+03 -0.00000000e+00  1.07e+00 2.28e+02  3.75e+02     0s
# INFO:gurobipy:   1  -8.49522767e+03 -1.69690133e+03  4.52e-01 7.09e+02  1.05e+02     0s
# INFO:gurobipy:   2  -4.00912302e+03 -5.80513892e+02  9.98e-05 2.28e+02  2.94e+01     0s
# INFO:gurobipy:   3  -8.22454559e+02  9.71273521e+01  3.85e-06 3.21e+01  4.33e+00     0s
# INFO:gurobipy:   4  -2.13367643e+02  8.31079888e+01  1.35e-07 2.20e+00  7.56e-01     0s
# INFO:gurobipy:   5  -1.10731900e+01  7.71420496e+01  3.55e-08 5.65e-01  1.89e-01     0s
# INFO:gurobipy:   6   2.24284267e+01  6.09159139e+01  3.88e-08 1.73e-02  7.63e-02     0s
# INFO:gurobipy:   7   3.97373546e+01  4.78231869e+01  2.68e-08 2.50e-08  1.60e-02     0s
# INFO:gurobipy:   8   4.27159585e+01  4.55360271e+01  1.84e-08 1.40e-08  5.62e-03     0s
# INFO:gurobipy:   9   4.37209250e+01  4.46852562e+01  9.20e-09 4.60e-05  1.90e-03     0s
# INFO:gurobipy:  10   4.39745418e+01  4.42441813e+01  6.00e-09 6.80e-09  5.33e-04     0s
# INFO:gurobipy:  11   4.40342594e+01  4.41224282e+01  1.28e-09 5.39e-09  1.75e-04     0s
# INFO:gurobipy:  12   4.40510308e+01  4.40601172e+01  7.60e-10 2.64e-09  1.79e-05     0s
# INFO:gurobipy:  13   4.40524984e+01  4.40525507e+01  1.56e-10 8.96e-11  1.02e-07     0s
# INFO:gurobipy:  14   4.40525250e+01  4.40525251e+01  2.52e-13 3.64e-12  1.02e-10     0s
# INFO:gurobipy:
# INFO:gurobipy:Barrier solved model in 14 iterations and 0.02 seconds (0.00 work units)
# INFO:gurobipy:Optimal objective 4.40525250e+01
# INFO:gurobipy:
# INFO:linopy.constants: Optimization successful:
# Status: ok
# Termination condition: optimal
# Solution: 296 primals, 689 duals
# Objective: 4.41e+01
# Solver: gurobi
# Runtime: 0.02s
# Dual bound: 4.41e+01
# Solver model: available
# Solver message: 2
#
# INFO:pypsa.optimization.optimize:The shadow-prices of the constraints Generator-ext-p-lower, Generator-ext-p-upper, Line-ext-s-lower, Line-ext-s-upper, StorageUnit-ext-p_dispatch-lower, StorageUnit-ext-p_dispatch-upper, StorageUnit-ext-p_store-lower, StorageUnit-ext-p_store-upper, StorageUnit-ext-state_of_charge-lower, StorageUnit-ext-state_of_charge-upper, StorageUnit-energy_balance, budget were not assigned to the network.
# INFO:linopy.model: Solve problem using Gurobi solver
# INFO:linopy.model:Solver options:
#  - Method: 2
#  - Crossover: 0
#  - log_to_console: False
# INFO:linopy.io: Writing time: 0.05s
# Set parameter Username
# INFO:gurobipy:Set parameter Username
# Academic license - for non-commercial use only - expires 2026-08-25
# INFO:gurobipy:Academic license - for non-commercial use only - expires 2026-08-25
# Read LP format model from file /tmp/linopy-problem-esappxvf.lp
# INFO:gurobipy:Read LP format model from file /tmp/linopy-problem-esappxvf.lp
# Reading time = 0.00 seconds
# INFO:gurobipy:Reading time = 0.00 seconds
# obj: 689 rows, 296 columns, 1332 nonzeros
# INFO:gurobipy:obj: 689 rows, 296 columns, 1332 nonzeros
# Set parameter Method to value 2
# INFO:gurobipy:Set parameter Method to value 2
# Set parameter Crossover to value 0
# INFO:gurobipy:Set parameter Crossover to value 0
# Set parameter LogToConsole to value 0
# INFO:gurobipy:Set parameter LogToConsole to value 0
# INFO:gurobipy:Gurobi Optimizer version 12.0.3 build v12.0.3rc0 (linux64 - "Linux Mint 22")
# INFO:gurobipy:
# INFO:gurobipy:CPU model: Intel(R) Core(TM) i7-10610U CPU @ 1.80GHz, instruction set [SSE2|AVX|AVX2]
# INFO:gurobipy:Thread count: 4 physical cores, 8 logical processors, using up to 8 threads
# INFO:gurobipy:
# INFO:gurobipy:Non-default parameters:
# INFO:gurobipy:Method  2
# INFO:gurobipy:Crossover  0
# INFO:gurobipy:LogToConsole  0
# INFO:gurobipy:
# INFO:gurobipy:Optimize a model with 689 rows, 296 columns and 1332 nonzeros
# INFO:gurobipy:Model fingerprint: 0xc2c56255
# INFO:gurobipy:Coefficient statistics:
# INFO:gurobipy:  Matrix range     [4e-02, 2e+03]
# INFO:gurobipy:  Objective range  [2e-11, 1e+00]
# INFO:gurobipy:  Bounds range     [0e+00, 0e+00]
# INFO:gurobipy:  RHS range        [2e+02, 7e+05]
# INFO:gurobipy:Presolve removed 124 rows and 334 columns
# INFO:gurobipy:Presolve time: 0.00s
# INFO:gurobipy:Presolved: 172 rows, 355 columns, 1578 nonzeros
# INFO:gurobipy:Ordering time: 0.00s
# INFO:gurobipy:
# INFO:gurobipy:Barrier statistics:
# INFO:gurobipy: Free vars  : 6
# INFO:gurobipy: AA' NZ     : 1.490e+03
# INFO:gurobipy: Factor NZ  : 3.248e+03
# INFO:gurobipy: Factor Ops : 6.994e+04 (less than 1 second per iteration)
# INFO:gurobipy: Threads    : 1
# INFO:gurobipy:
# INFO:gurobipy:                  Objective                Residual
# INFO:gurobipy:Iter       Primal          Dual         Primal    Dual     Compl     Time
# INFO:gurobipy:   0  -9.06313215e+03 -0.00000000e+00  9.01e-01 2.28e+02  3.24e+02     0s
# INFO:gurobipy:   1  -8.48063851e+03 -3.53427458e+02  1.89e-01 6.04e+02  7.53e+01     0s
# INFO:gurobipy:   2  -3.20578257e+03  9.99320745e-02  5.12e-05 1.61e+02  1.78e+01     0s
# INFO:gurobipy:   3  -7.73828885e+02  4.33582098e+01  3.83e-06 3.12e+01  3.16e+00     0s
# INFO:gurobipy:   4  -2.46070716e+02  3.40986431e+01  3.76e-07 7.20e+00  8.03e-01     0s
# INFO:gurobipy:   5  -8.91109481e+01  2.37769271e+01  8.68e-08 2.82e+00  2.87e-01     0s
# INFO:gurobipy:   6  -1.55384787e+01  1.17905310e+01  6.23e-08 3.82e-01  5.83e-02     0s
# INFO:gurobipy:   7  -4.96347635e+00  1.25320849e+00  1.16e-07 1.69e-08  1.21e-02     0s
# INFO:gurobipy:   8  -5.09518845e-01  2.57640284e-01  2.78e-08 8.47e-09  1.50e-03     0s
# INFO:gurobipy:   9  -3.82173505e-03  9.17346578e-03  3.08e-09 7.09e-10  2.53e-05     0s
# INFO:gurobipy:  10  -3.48298993e-06  9.53108320e-06  4.99e-11 2.73e-12  2.53e-08     0s
# INFO:gurobipy:  11  -1.81819504e-06  2.50896172e-06  6.06e-10 1.82e-12  8.19e-09     0s
# INFO:gurobipy:  12  -4.23097486e-08  3.24772678e-07  4.63e-10 3.45e-12  7.88e-10     0s
# INFO:gurobipy:  13  -2.45855638e-07  3.19812567e-07  1.66e-09 5.64e-10  2.47e-11     0s
# INFO:gurobipy:  14  -1.51074310e-07  3.16853292e-07  1.96e-09 5.01e-11  2.35e-12     0s
# INFO:gurobipy:
# INFO:gurobipy:Barrier solved model in 14 iterations and 0.01 seconds (0.00 work units)
# INFO:gurobipy:Optimal objective -1.51074310e-07
# INFO:gurobipy:
# INFO:linopy.constants: Optimization successful:
# Status: ok
# Termination condition: optimal
# Solution: 296 primals, 689 duals
# Objective: 3.17e-07
# Solver: gurobi
# Runtime: 0.02s
# Dual bound: 3.17e-07
# Solver model: available
# Solver message: 2
#
# INFO:pypsa.optimization.optimize:The shadow-prices of the constraints Generator-ext-p-lower, Generator-ext-p-upper, Line-ext-s-lower, Line-ext-s-upper, StorageUnit-ext-p_dispatch-lower, StorageUnit-ext-p_dispatch-upper, StorageUnit-ext-p_store-lower, StorageUnit-ext-p_store-upper, StorageUnit-ext-state_of_charge-lower, StorageUnit-ext-state_of_charge-upper, StorageUnit-energy_balance, budget were not assigned to the network.
# INFO:linopy.model: Solve problem using Gurobi solver
# INFO:linopy.model:Solver options:
#  - Method: 2
#  - Crossover: 0
#  - log_to_console: False
# INFO:linopy.io: Writing time: 0.05s
# Set parameter Username
# INFO:gurobipy:Set parameter Username
# Academic license - for non-commercial use only - expires 2026-08-25
# INFO:gurobipy:Academic license - for non-commercial use only - expires 2026-08-25
# Read LP format model from file /tmp/linopy-problem-jeavfkg4.lp
# INFO:gurobipy:Read LP format model from file /tmp/linopy-problem-jeavfkg4.lp
# Reading time = 0.00 seconds
# INFO:gurobipy:Reading time = 0.00 seconds
# obj: 689 rows, 296 columns, 1332 nonzeros
# INFO:gurobipy:obj: 689 rows, 296 columns, 1332 nonzeros
# Set parameter Method to value 2
# INFO:gurobipy:Set parameter Method to value 2
# Set parameter Crossover to value 0
# INFO:gurobipy:Set parameter Crossover to value 0
# Set parameter LogToConsole to value 0
# INFO:gurobipy:Set parameter LogToConsole to value 0
# INFO:gurobipy:Gurobi Optimizer version 12.0.3 build v12.0.3rc0 (linux64 - "Linux Mint 22")
# INFO:gurobipy:
# INFO:gurobipy:CPU model: Intel(R) Core(TM) i7-10610U CPU @ 1.80GHz, instruction set [SSE2|AVX|AVX2]
# INFO:gurobipy:Thread count: 4 physical cores, 8 logical processors, using up to 8 threads
# INFO:gurobipy:
# INFO:gurobipy:Non-default parameters:
# INFO:gurobipy:Method  2
# INFO:gurobipy:Crossover  0
# INFO:gurobipy:LogToConsole  0
# INFO:gurobipy:
# INFO:gurobipy:Optimize a model with 689 rows, 296 columns and 1332 nonzeros
# INFO:gurobipy:Model fingerprint: 0x329cbe6e
# INFO:gurobipy:Coefficient statistics:
# INFO:gurobipy:  Matrix range     [4e-02, 2e+03]
# INFO:gurobipy:  Objective range  [4e-02, 1e+00]
# INFO:gurobipy:  Bounds range     [0e+00, 0e+00]
# INFO:gurobipy:  RHS range        [2e+02, 7e+05]
# INFO:gurobipy:Presolve removed 124 rows and 334 columns
# INFO:gurobipy:Presolve time: 0.00s
# INFO:gurobipy:Presolved: 172 rows, 355 columns, 1578 nonzeros
# INFO:gurobipy:Ordering time: 0.00s
# INFO:gurobipy:
# INFO:gurobipy:Barrier statistics:
# INFO:gurobipy: Free vars  : 6
# INFO:gurobipy: AA' NZ     : 1.490e+03
# INFO:gurobipy: Factor NZ  : 3.248e+03
# INFO:gurobipy: Factor Ops : 6.994e+04 (less than 1 second per iteration)
# INFO:gurobipy: Threads    : 1
# INFO:gurobipy:
# INFO:gurobipy:                  Objective                Residual
# INFO:gurobipy:Iter       Primal          Dual         Primal    Dual     Compl     Time
# INFO:gurobipy:   0  -1.04926756e+04 -0.00000000e+00  1.22e+00 2.28e+02  4.28e+02     0s
# INFO:gurobipy:   1  -1.00268930e+04 -1.76251084e+03  5.24e-01 7.09e+02  1.20e+02     0s
# INFO:gurobipy:   2  -4.91353190e+03 -3.86285524e+02  4.83e-02 2.16e+02  3.47e+01     0s
# INFO:gurobipy:   3  -1.20852123e+03  1.02630536e+02  2.30e-03 2.54e+01  5.05e+00     0s
# INFO:gurobipy:   4  -3.65239507e+02  1.16792250e+01  7.95e-05 1.16e+00  8.12e-01     0s
# INFO:gurobipy:   5  -1.37675238e+02 -3.70940413e+00  2.71e-05 1.50e-01  2.68e-01     0s
# INFO:gurobipy:   6  -9.88322730e+01 -2.65287620e+01  1.17e-05 3.51e-02  1.43e-01     0s
# INFO:gurobipy:   7  -7.55282356e+01 -4.13401784e+01  4.99e-06 1.53e-02  6.71e-02     0s
# INFO:gurobipy:   8  -6.20464725e+01 -4.88346113e+01  8.96e-07 4.65e-03  2.60e-02     0s
# INFO:gurobipy:   9  -5.75094018e+01 -5.45757423e+01  1.85e-07 4.58e-04  5.77e-03     0s
# INFO:gurobipy:  10  -5.63655282e+01 -5.58240666e+01  1.80e-08 7.14e-09  1.06e-03     0s
# INFO:gurobipy:  11  -5.61750973e+01 -5.60455348e+01  6.13e-09 1.18e-08  2.55e-04     0s
# INFO:gurobipy:  12  -5.61333035e+01 -5.61251091e+01  5.61e-10 1.71e-09  1.60e-05     0s
# INFO:gurobipy:  13  -5.61280987e+01 -5.61280904e+01  2.05e-11 2.73e-10  1.61e-08     0s
# INFO:gurobipy:  14  -5.61280934e+01 -5.61280934e+01  5.57e-13 9.09e-13  1.61e-11     0s
# INFO:gurobipy:
# INFO:gurobipy:Barrier solved model in 14 iterations and 0.01 seconds (0.00 work units)
# INFO:gurobipy:Optimal objective -5.61280934e+01
# INFO:gurobipy:
# INFO:linopy.constants: Optimization successful:
# Status: ok
# Termination condition: optimal
# Solution: 296 primals, 689 duals
# Objective: -5.61e+01
# Solver: gurobi
# Runtime: 0.01s
# Dual bound: -5.61e+01
# Solver model: available
# Solver message: 2
#
# INFO:pypsa.optimization.optimize:The shadow-prices of the constraints Generator-ext-p-lower, Generator-ext-p-upper, Line-ext-s-lower, Line-ext-s-upper, StorageUnit-ext-p_dispatch-lower, StorageUnit-ext-p_dispatch-upper, StorageUnit-ext-p_store-lower, StorageUnit-ext-p_store-upper, StorageUnit-ext-state_of_charge-lower, StorageUnit-ext-state_of_charge-upper, StorageUnit-energy_balance, budget were not assigned to the network.

# %% [markdown]
# ### 2.3 Inspect the alternatives

# %%
mga_total_capacities = pd.concat((
    pd.DataFrame(mga_alternatives[x]).fillna(0).round(2).sum(axis=1) for x in mga_alternatives
), axis=1)

mga_spatial_capacities = pd.concat((
    pd.DataFrame(mga_spatial_alternatives[x]).fillna(0).round(2).sum(axis=1) for x in mga_alternatives
), axis=1)

# %%
mga_total_capacities.plot.bar()
# Out:
# <Axes: >

# %%
mga_spatial_capacities.plot.bar()
# Out:
# <Axes: >

# %%
mga_weights = pd.concat((
    pd.DataFrame(mga_weights[x]).fillna(0).round(2).sum(axis=1) for x in mga_weights
), axis=1)
mga_weights
# Out:
#                 0     1     2     3     4     5
# OCGT          0.0  0.06  0.22  0.20  0.99 -0.11
# solar_bus1    0.0  0.00  0.00  0.11  0.00 -0.13
# wind_bus1     0.0  0.00  0.92  0.09  0.00  0.06
# solar_bus2    0.0  0.00  0.00  0.15  0.00  0.05
# wind_bus2     0.0  0.95  0.00  0.92  0.00  0.96
# battery_bus1  0.0  0.00  0.32  0.16  0.13  0.04
# battery_bus2  0.0  0.31  0.00  0.23  0.00  0.22

# %% [markdown]
# ## 3. Generate alternative solutions with SPORES MGA (diversificaton + intensification)
# This time, we first identify an extreme of the solution space (highest solar capacity while lowest wind capacity), then generate diversity around it. This is achieved via the 'intensification' feature of SPORES.

# %% [markdown]
# ### 3.1 Load and check new MGA configuration

# %%
with open("../../configs/test_config_spores_diversify_intensify.yaml") as yf:
    test_config = SPORESConfig.model_validate(yaml.safe_load(yf))
test_config
# Out:
# {'config_name': 'spores',
#  'model_interface': 'pypsa',
#  'cost_slack': 0.2,
#  'alternatives': 5,
#  'spatially_explicit': True,
#  'diversification_coefficient': 'auto',
#  'intensification_coefficient': [1, -1],
#  'diversified_technologies': ['wind', 'solar', 'gas', 'battery'],
#  'intensified_technologies': ['wind', 'solar']}

# %% [markdown]
# ### 3.2 Run the SPORES algorithm with the new configuration

# %%
mga_alternatives, mga_spatial_alternatives, mga_weights = spores_algorithm_adaptive(test_config, n)
# Out:
# WARNING:pypsa.consistency:Encountered nan's in varying data 'v_ang' for columns ['bus1', 'bus2'] of component 'Bus'.
# WARNING:pypsa.consistency:The following lines have zero x, which could break the linear load flow:
# Index(['line'], dtype='object', name='name')
# WARNING:pypsa.consistency:The following lines have zero r, which could break the linear load flow:
# Index(['line'], dtype='object', name='name')
# INFO:linopy.model: Solve problem using Gurobi solver
# INFO:linopy.model:Solver options:
#  - Method: 2
#  - Crossover: 0
#  - log_to_console: False
# INFO:linopy.io: Writing time: 0.06s
# Technologies [] not found in the model
# Set parameter Username
# INFO:gurobipy:Set parameter Username
# Academic license - for non-commercial use only - expires 2026-08-25
# INFO:gurobipy:Academic license - for non-commercial use only - expires 2026-08-25
# Read LP format model from file /tmp/linopy-problem-v9ogw81w.lp
# INFO:gurobipy:Read LP format model from file /tmp/linopy-problem-v9ogw81w.lp
# Reading time = 0.00 seconds
# INFO:gurobipy:Reading time = 0.00 seconds
# obj: 689 rows, 296 columns, 1332 nonzeros
# INFO:gurobipy:obj: 689 rows, 296 columns, 1332 nonzeros
# Set parameter Method to value 2
# INFO:gurobipy:Set parameter Method to value 2
# Set parameter Crossover to value 0
# INFO:gurobipy:Set parameter Crossover to value 0
# Set parameter LogToConsole to value 0
# INFO:gurobipy:Set parameter LogToConsole to value 0
# INFO:gurobipy:Gurobi Optimizer version 12.0.3 build v12.0.3rc0 (linux64 - "Linux Mint 22")
# INFO:gurobipy:
# INFO:gurobipy:CPU model: Intel(R) Core(TM) i7-10610U CPU @ 1.80GHz, instruction set [SSE2|AVX|AVX2]
# INFO:gurobipy:Thread count: 4 physical cores, 8 logical processors, using up to 8 threads
# INFO:gurobipy:
# INFO:gurobipy:Non-default parameters:
# INFO:gurobipy:Method  2
# INFO:gurobipy:Crossover  0
# INFO:gurobipy:LogToConsole  0
# INFO:gurobipy:
# INFO:gurobipy:Optimize a model with 689 rows, 296 columns and 1332 nonzeros
# INFO:gurobipy:Model fingerprint: 0x0be50ed7
# INFO:gurobipy:Coefficient statistics:
# INFO:gurobipy:  Matrix range     [4e-02, 2e+03]
# INFO:gurobipy:  Objective range  [5e-01, 5e-01]
# INFO:gurobipy:  Bounds range     [0e+00, 0e+00]
# INFO:gurobipy:  RHS range        [2e+02, 7e+05]
# INFO:gurobipy:Presolve removed 124 rows and 334 columns
# INFO:gurobipy:Presolve time: 0.00s
# INFO:gurobipy:Presolved: 172 rows, 355 columns, 1578 nonzeros
# INFO:gurobipy:Ordering time: 0.00s
# INFO:gurobipy:
# INFO:gurobipy:Barrier statistics:
# INFO:gurobipy: Free vars  : 6
# INFO:gurobipy: AA' NZ     : 1.490e+03
# INFO:gurobipy: Factor NZ  : 3.248e+03
# INFO:gurobipy: Factor Ops : 6.994e+04 (less than 1 second per iteration)
# INFO:gurobipy: Threads    : 1
# INFO:gurobipy:
# INFO:gurobipy:                  Objective                Residual
# INFO:gurobipy:Iter       Primal          Dual         Primal    Dual     Compl     Time
# INFO:gurobipy:   0  -8.51625142e+03 -0.00000000e+00  9.01e-01 2.28e+02  3.21e+02     0s
# INFO:gurobipy:   1  -8.18603161e+03 -1.18674532e+03  3.75e-01 5.58e+02  7.51e+01     0s
# INFO:gurobipy:   2  -5.41866369e+03 -3.72573982e+02  1.38e-01 1.74e+02  2.88e+01     0s
# INFO:gurobipy:   3  -1.35474778e+03  3.01616069e+01  5.52e-03 3.05e+01  5.04e+00     0s
# INFO:gurobipy:   4  -4.43089390e+02 -3.36803630e+01  5.44e-04 1.11e+01  1.51e+00     0s
# INFO:gurobipy:   5  -2.29947317e+02 -8.89508950e+01  6.28e-05 5.21e+00  5.33e-01     0s
# INFO:gurobipy:   6  -1.99708763e+02 -1.22358138e+02  3.80e-05 1.32e+00  2.18e-01     0s
# INFO:gurobipy:   7  -1.66328631e+02 -1.40943708e+02  9.41e-06 1.62e-01  5.84e-02     0s
# INFO:gurobipy:   8  -1.52851685e+02 -1.46636816e+02  1.38e-06 4.56e-02  1.46e-02     0s
# INFO:gurobipy:   9  -1.49814471e+02 -1.48533688e+02  9.11e-08 1.33e-02  3.22e-03     0s
# INFO:gurobipy:  10  -1.49528159e+02 -1.49403713e+02  1.38e-08 7.54e-04  2.84e-04     0s
# INFO:gurobipy:  11  -1.49469253e+02 -1.49464997e+02  3.31e-10 1.63e-05  9.30e-06     0s
# INFO:gurobipy:  12  -1.49467632e+02 -1.49467627e+02  3.31e-12 3.52e-11  9.27e-09     0s
# INFO:gurobipy:  13  -1.49467630e+02 -1.49467630e+02  1.39e-13 1.91e-12  9.27e-12     0s
# INFO:gurobipy:
# INFO:gurobipy:Barrier solved model in 13 iterations and 0.02 seconds (0.00 work units)
# INFO:gurobipy:Optimal objective -1.49467630e+02
# INFO:gurobipy:
# INFO:linopy.constants: Optimization successful:
# Status: ok
# Termination condition: optimal
# Solution: 296 primals, 689 duals
# Objective: -1.49e+02
# Solver: gurobi
# Runtime: 0.02s
# Dual bound: -1.49e+02
# Solver model: available
# Solver message: 2
#
# INFO:pypsa.optimization.optimize:The shadow-prices of the constraints Generator-ext-p-lower, Generator-ext-p-upper, Line-ext-s-lower, Line-ext-s-upper, StorageUnit-ext-p_dispatch-lower, StorageUnit-ext-p_dispatch-upper, StorageUnit-ext-p_store-lower, StorageUnit-ext-p_store-upper, StorageUnit-ext-state_of_charge-lower, StorageUnit-ext-state_of_charge-upper, StorageUnit-energy_balance, budget were not assigned to the network.
# INFO:linopy.model: Solve problem using Gurobi solver
# INFO:linopy.model:Solver options:
#  - Method: 2
#  - Crossover: 0
#  - log_to_console: False
# INFO:linopy.io: Writing time: 0.05s
# Set parameter Username
# INFO:gurobipy:Set parameter Username
# Academic license - for non-commercial use only - expires 2026-08-25
# INFO:gurobipy:Academic license - for non-commercial use only - expires 2026-08-25
# Read LP format model from file /tmp/linopy-problem-2x2_bejm.lp
# INFO:gurobipy:Read LP format model from file /tmp/linopy-problem-2x2_bejm.lp
# Reading time = 0.00 seconds
# INFO:gurobipy:Reading time = 0.00 seconds
# obj: 689 rows, 296 columns, 1332 nonzeros
# INFO:gurobipy:obj: 689 rows, 296 columns, 1332 nonzeros
# Set parameter Method to value 2
# INFO:gurobipy:Set parameter Method to value 2
# Set parameter Crossover to value 0
# INFO:gurobipy:Set parameter Crossover to value 0
# Set parameter LogToConsole to value 0
# INFO:gurobipy:Set parameter LogToConsole to value 0
# INFO:gurobipy:Gurobi Optimizer version 12.0.3 build v12.0.3rc0 (linux64 - "Linux Mint 22")
# INFO:gurobipy:
# INFO:gurobipy:CPU model: Intel(R) Core(TM) i7-10610U CPU @ 1.80GHz, instruction set [SSE2|AVX|AVX2]
# INFO:gurobipy:Thread count: 4 physical cores, 8 logical processors, using up to 8 threads
# INFO:gurobipy:
# INFO:gurobipy:Non-default parameters:
# INFO:gurobipy:Method  2
# INFO:gurobipy:Crossover  0
# INFO:gurobipy:LogToConsole  0
# INFO:gurobipy:
# INFO:gurobipy:Optimize a model with 689 rows, 296 columns and 1332 nonzeros
# INFO:gurobipy:Model fingerprint: 0xc8cb43e4
# INFO:gurobipy:Coefficient statistics:
# INFO:gurobipy:  Matrix range     [4e-02, 2e+03]
# INFO:gurobipy:  Objective range  [6e-12, 6e-01]
# INFO:gurobipy:  Bounds range     [0e+00, 0e+00]
# INFO:gurobipy:  RHS range        [2e+02, 7e+05]
# INFO:gurobipy:Presolve removed 124 rows and 334 columns
# INFO:gurobipy:Presolve time: 0.00s
# INFO:gurobipy:Presolved: 172 rows, 355 columns, 1578 nonzeros
# INFO:gurobipy:Ordering time: 0.00s
# INFO:gurobipy:
# INFO:gurobipy:Barrier statistics:
# INFO:gurobipy: Free vars  : 6
# INFO:gurobipy: AA' NZ     : 1.490e+03
# INFO:gurobipy: Factor NZ  : 3.248e+03
# INFO:gurobipy: Factor Ops : 6.994e+04 (less than 1 second per iteration)
# INFO:gurobipy: Threads    : 1
# INFO:gurobipy:
# INFO:gurobipy:                  Objective                Residual
# INFO:gurobipy:Iter       Primal          Dual         Primal    Dual     Compl     Time
# INFO:gurobipy:   0  -8.16326392e+03 -0.00000000e+00  9.01e-01 2.28e+02  3.18e+02     0s
# INFO:gurobipy:   1  -7.80834995e+03 -1.11213070e+03  3.52e-01 5.59e+02  7.45e+01     0s
# INFO:gurobipy:   2  -4.65414217e+03 -2.07135009e+01  8.65e-02 1.43e+02  2.39e+01     0s
# INFO:gurobipy:   3  -9.34306723e+02  1.72741138e+02  4.43e-03 2.10e+01  3.68e+00     0s
# INFO:gurobipy:   4  -2.33684476e+02  1.09275752e+02  4.57e-04 8.25e+00  1.14e+00     0s
# INFO:gurobipy:   5  -1.37939985e+02  5.22655837e+01  1.86e-04 4.39e+00  6.00e-01     0s
# INFO:gurobipy:   6  -8.49485372e+01  1.93228956e+01  8.43e-05 2.20e+00  2.98e-01     0s
# INFO:gurobipy:   7  -6.26322583e+01 -1.05753690e+01  4.63e-05 8.63e-01  1.42e-01     0s
# INFO:gurobipy:   8  -5.83175104e+01 -1.61447105e+01  3.67e-05 6.55e-01  1.13e-01     0s
# INFO:gurobipy:   9  -4.32294576e+01 -2.59093459e+01  1.06e-05 3.39e-01  5.08e-02     0s
# INFO:gurobipy:  10  -3.85909429e+01 -3.10154103e+01  3.91e-06 1.26e-01  2.12e-02     0s
# INFO:gurobipy:  11  -3.67215799e+01 -3.29349931e+01  2.09e-06 5.14e-02  1.00e-02     0s
# INFO:gurobipy:  12  -3.45724112e+01 -3.40012723e+01  2.35e-07 2.27e-03  1.24e-03     0s
# INFO:gurobipy:  13  -3.42386838e+01 -3.42178429e+01  2.58e-09 1.26e-08  4.09e-05     0s
# INFO:gurobipy:  14  -3.42308899e+01 -3.42308480e+01  2.67e-11 5.23e-10  8.15e-08     0s
# INFO:gurobipy:  15  -3.42308613e+01 -3.42308613e+01  7.22e-14 3.64e-12  8.39e-14     0s
# INFO:gurobipy:
# INFO:gurobipy:Barrier solved model in 15 iterations and 0.02 seconds (0.00 work units)
# INFO:gurobipy:Optimal objective -3.42308613e+01
# INFO:gurobipy:
# INFO:linopy.constants: Optimization successful:
# Status: ok
# Termination condition: optimal
# Solution: 296 primals, 689 duals
# Objective: -3.42e+01
# Solver: gurobi
# Runtime: 0.02s
# Dual bound: -3.42e+01
# Solver model: available
# Solver message: 2
#
# INFO:pypsa.optimization.optimize:The shadow-prices of the constraints Generator-ext-p-lower, Generator-ext-p-upper, Line-ext-s-lower, Line-ext-s-upper, StorageUnit-ext-p_dispatch-lower, StorageUnit-ext-p_dispatch-upper, StorageUnit-ext-p_store-lower, StorageUnit-ext-p_store-upper, StorageUnit-ext-state_of_charge-lower, StorageUnit-ext-state_of_charge-upper, StorageUnit-energy_balance, budget were not assigned to the network.
# INFO:linopy.model: Solve problem using Gurobi solver
# INFO:linopy.model:Solver options:
#  - Method: 2
#  - Crossover: 0
#  - log_to_console: False
# INFO:linopy.io: Writing time: 0.05s
# Set parameter Username
# INFO:gurobipy:Set parameter Username
# Academic license - for non-commercial use only - expires 2026-08-25
# INFO:gurobipy:Academic license - for non-commercial use only - expires 2026-08-25
# Read LP format model from file /tmp/linopy-problem-wcd4e09o.lp
# INFO:gurobipy:Read LP format model from file /tmp/linopy-problem-wcd4e09o.lp
# Reading time = 0.00 seconds
# INFO:gurobipy:Reading time = 0.00 seconds
# obj: 689 rows, 296 columns, 1332 nonzeros
# INFO:gurobipy:obj: 689 rows, 296 columns, 1332 nonzeros
# Set parameter Method to value 2
# INFO:gurobipy:Set parameter Method to value 2
# Set parameter Crossover to value 0
# INFO:gurobipy:Set parameter Crossover to value 0
# Set parameter LogToConsole to value 0
# INFO:gurobipy:Set parameter LogToConsole to value 0
# INFO:gurobipy:Gurobi Optimizer version 12.0.3 build v12.0.3rc0 (linux64 - "Linux Mint 22")
# INFO:gurobipy:
# INFO:gurobipy:CPU model: Intel(R) Core(TM) i7-10610U CPU @ 1.80GHz, instruction set [SSE2|AVX|AVX2]
# INFO:gurobipy:Thread count: 4 physical cores, 8 logical processors, using up to 8 threads
# INFO:gurobipy:
# INFO:gurobipy:Non-default parameters:
# INFO:gurobipy:Method  2
# INFO:gurobipy:Crossover  0
# INFO:gurobipy:LogToConsole  0
# INFO:gurobipy:
# INFO:gurobipy:Optimize a model with 689 rows, 296 columns and 1332 nonzeros
# INFO:gurobipy:Model fingerprint: 0x43ae7a39
# INFO:gurobipy:Coefficient statistics:
# INFO:gurobipy:  Matrix range     [4e-02, 2e+03]
# INFO:gurobipy:  Objective range  [8e-02, 6e-01]
# INFO:gurobipy:  Bounds range     [0e+00, 0e+00]
# INFO:gurobipy:  RHS range        [2e+02, 7e+05]
# INFO:gurobipy:Presolve removed 124 rows and 334 columns
# INFO:gurobipy:Presolve time: 0.00s
# INFO:gurobipy:Presolved: 172 rows, 355 columns, 1578 nonzeros
# INFO:gurobipy:Ordering time: 0.00s
# INFO:gurobipy:
# INFO:gurobipy:Barrier statistics:
# INFO:gurobipy: Free vars  : 6
# INFO:gurobipy: AA' NZ     : 1.490e+03
# INFO:gurobipy: Factor NZ  : 3.248e+03
# INFO:gurobipy: Factor Ops : 6.994e+04 (less than 1 second per iteration)
# INFO:gurobipy: Threads    : 1
# INFO:gurobipy:
# INFO:gurobipy:                  Objective                Residual
# INFO:gurobipy:Iter       Primal          Dual         Primal    Dual     Compl     Time
# INFO:gurobipy:   0  -8.47846172e+03 -0.00000000e+00  9.01e-01 2.28e+02  3.20e+02     0s
# INFO:gurobipy:   1  -8.13125416e+03 -8.43619375e+02  3.48e-01 5.89e+02  7.74e+01     0s
# INFO:gurobipy:   2  -5.50203995e+03 -3.13299810e+02  1.36e-01 1.55e+02  2.79e+01     0s
# INFO:gurobipy:   3  -1.69586631e+03 -1.18041655e+02  3.86e-03 2.94e+01  5.39e+00     0s
# INFO:gurobipy:   4  -4.52589769e+02 -7.62622936e+01  7.36e-04 1.39e+01  1.85e+00     0s
# INFO:gurobipy:   5  -2.27610185e+02 -7.87487236e+01  1.41e-04 7.71e+00  7.85e-01     0s
# INFO:gurobipy:   6  -1.48185584e+02 -6.95612382e+01  4.19e-05 2.47e+00  2.91e-01     0s
# INFO:gurobipy:   7  -1.28458600e+02 -8.45204620e+01  2.54e-05 6.78e-01  1.26e-01     0s
# INFO:gurobipy:   8  -1.06962749e+02 -8.94408967e+01  8.36e-06 1.64e-01  4.45e-02     0s
# INFO:gurobipy:   9  -9.83503755e+01 -9.27200671e+01  2.22e-06 6.35e-02  1.50e-02     0s
# INFO:gurobipy:  10  -9.54211288e+01 -9.44410461e+01  1.89e-07 7.80e-03  2.43e-03     0s
# INFO:gurobipy:  11  -9.49906484e+01 -9.48238569e+01  8.01e-09 1.92e-03  4.55e-04     0s
# INFO:gurobipy:  12  -9.49615325e+01 -9.49514320e+01  2.20e-09 1.34e-05  2.09e-05     0s
# INFO:gurobipy:  13  -9.49567429e+01 -9.49567322e+01  6.62e-12 1.58e-10  2.09e-08     0s
# INFO:gurobipy:  14  -9.49567381e+01 -9.49567381e+01  7.11e-14 1.82e-12  2.09e-11     0s
# INFO:gurobipy:
# INFO:gurobipy:Barrier solved model in 14 iterations and 0.02 seconds (0.00 work units)
# INFO:gurobipy:Optimal objective -9.49567381e+01
# INFO:gurobipy:
# INFO:linopy.constants: Optimization successful:
# Status: ok
# Termination condition: optimal
# Solution: 296 primals, 689 duals
# Objective: -9.50e+01
# Solver: gurobi
# Runtime: 0.02s
# Dual bound: -9.50e+01
# Solver model: available
# Solver message: 2
#
# INFO:pypsa.optimization.optimize:The shadow-prices of the constraints Generator-ext-p-lower, Generator-ext-p-upper, Line-ext-s-lower, Line-ext-s-upper, StorageUnit-ext-p_dispatch-lower, StorageUnit-ext-p_dispatch-upper, StorageUnit-ext-p_store-lower, StorageUnit-ext-p_store-upper, StorageUnit-ext-state_of_charge-lower, StorageUnit-ext-state_of_charge-upper, StorageUnit-energy_balance, budget were not assigned to the network.
# INFO:linopy.model: Solve problem using Gurobi solver
# INFO:linopy.model:Solver options:
#  - Method: 2
#  - Crossover: 0
#  - log_to_console: False
# INFO:linopy.io: Writing time: 0.06s
# Set parameter Username
# INFO:gurobipy:Set parameter Username
# Academic license - for non-commercial use only - expires 2026-08-25
# INFO:gurobipy:Academic license - for non-commercial use only - expires 2026-08-25
# Read LP format model from file /tmp/linopy-problem-ty1pcqd8.lp
# INFO:gurobipy:Read LP format model from file /tmp/linopy-problem-ty1pcqd8.lp
# Reading time = 0.00 seconds
# INFO:gurobipy:Reading time = 0.00 seconds
# obj: 689 rows, 296 columns, 1332 nonzeros
# INFO:gurobipy:obj: 689 rows, 296 columns, 1332 nonzeros
# Set parameter Method to value 2
# INFO:gurobipy:Set parameter Method to value 2
# Set parameter Crossover to value 0
# INFO:gurobipy:Set parameter Crossover to value 0
# Set parameter LogToConsole to value 0
# INFO:gurobipy:Set parameter LogToConsole to value 0
# INFO:gurobipy:Gurobi Optimizer version 12.0.3 build v12.0.3rc0 (linux64 - "Linux Mint 22")
# INFO:gurobipy:
# INFO:gurobipy:CPU model: Intel(R) Core(TM) i7-10610U CPU @ 1.80GHz, instruction set [SSE2|AVX|AVX2]
# INFO:gurobipy:Thread count: 4 physical cores, 8 logical processors, using up to 8 threads
# INFO:gurobipy:
# INFO:gurobipy:Non-default parameters:
# INFO:gurobipy:Method  2
# INFO:gurobipy:Crossover  0
# INFO:gurobipy:LogToConsole  0
# INFO:gurobipy:
# INFO:gurobipy:Optimize a model with 689 rows, 296 columns and 1332 nonzeros
# INFO:gurobipy:Model fingerprint: 0x5edd1286
# INFO:gurobipy:Coefficient statistics:
# INFO:gurobipy:  Matrix range     [4e-02, 2e+03]
# INFO:gurobipy:  Objective range  [9e-02, 6e-01]
# INFO:gurobipy:  Bounds range     [0e+00, 0e+00]
# INFO:gurobipy:  RHS range        [2e+02, 7e+05]
# INFO:gurobipy:Presolve removed 124 rows and 334 columns
# INFO:gurobipy:Presolve time: 0.00s
# INFO:gurobipy:Presolved: 172 rows, 355 columns, 1578 nonzeros
# INFO:gurobipy:Ordering time: 0.00s
# INFO:gurobipy:
# INFO:gurobipy:Barrier statistics:
# INFO:gurobipy: Free vars  : 6
# INFO:gurobipy: AA' NZ     : 1.490e+03
# INFO:gurobipy: Factor NZ  : 3.248e+03
# INFO:gurobipy: Factor Ops : 6.994e+04 (less than 1 second per iteration)
# INFO:gurobipy: Threads    : 1
# INFO:gurobipy:
# INFO:gurobipy:                  Objective                Residual
# INFO:gurobipy:Iter       Primal          Dual         Primal    Dual     Compl     Time
# INFO:gurobipy:   0  -7.88042148e+03 -0.00000000e+00  9.01e-01 2.28e+02  3.17e+02     0s
# INFO:gurobipy:   1  -7.49678747e+03 -1.41238721e+03  3.75e-01 5.34e+02  7.28e+01     0s
# INFO:gurobipy:   2  -5.37577407e+03 -1.08959962e+03  1.56e-01 2.72e+02  3.74e+01     0s
# INFO:gurobipy:   3  -2.08230578e+03 -2.82340097e+02  1.18e-02 6.88e+01  9.61e+00     0s
# INFO:gurobipy:   4  -5.82615073e+02 -3.36359557e+01  1.74e-03 1.91e+01  2.48e+00     0s
# INFO:gurobipy:   5  -2.48411951e+02 -8.28892326e+01  2.16e-04 9.52e+00  9.01e-01     0s
# INFO:gurobipy:   6  -2.01731467e+02 -1.10270879e+02  7.41e-05 4.52e+00  4.40e-01     0s
# INFO:gurobipy:   7  -1.72267601e+02 -1.42171531e+02  1.43e-05 9.52e-01  1.18e-01     0s
# INFO:gurobipy:   8  -1.51611416e+02 -1.37735509e+02  3.57e-06 2.78e-01  4.58e-02     0s
# INFO:gurobipy:   9  -1.45654115e+02 -1.40591074e+02  1.08e-06 7.79e-02  1.52e-02     0s
# INFO:gurobipy:  10  -1.42593959e+02 -1.41520918e+02  6.12e-08 3.09e-02  4.25e-03     0s
# INFO:gurobipy:  11  -1.42153433e+02 -1.41897546e+02  1.45e-08 1.78e-03  6.32e-04     0s
# INFO:gurobipy:  12  -1.42020560e+02 -1.42009426e+02  4.07e-10 2.30e-05  2.36e-05     0s
# INFO:gurobipy:  13  -1.42014825e+02 -1.42014812e+02  7.51e-12 3.57e-10  2.36e-08     0s
# INFO:gurobipy:  14  -1.42014819e+02 -1.42014819e+02  2.46e-13 3.64e-12  2.36e-11     0s
# INFO:gurobipy:
# INFO:gurobipy:Barrier solved model in 14 iterations and 0.02 seconds (0.00 work units)
# INFO:gurobipy:Optimal objective -1.42014819e+02
# INFO:gurobipy:
# INFO:linopy.constants: Optimization successful:
# Status: ok
# Termination condition: optimal
# Solution: 296 primals, 689 duals
# Objective: -1.42e+02
# Solver: gurobi
# Runtime: 0.02s
# Dual bound: -1.42e+02
# Solver model: available
# Solver message: 2
#
# INFO:pypsa.optimization.optimize:The shadow-prices of the constraints Generator-ext-p-lower, Generator-ext-p-upper, Line-ext-s-lower, Line-ext-s-upper, StorageUnit-ext-p_dispatch-lower, StorageUnit-ext-p_dispatch-upper, StorageUnit-ext-p_store-lower, StorageUnit-ext-p_store-upper, StorageUnit-ext-state_of_charge-lower, StorageUnit-ext-state_of_charge-upper, StorageUnit-energy_balance, budget were not assigned to the network.
# INFO:linopy.model: Solve problem using Gurobi solver
# INFO:linopy.model:Solver options:
#  - Method: 2
#  - Crossover: 0
#  - log_to_console: False
# INFO:linopy.io: Writing time: 0.07s
# Set parameter Username
# INFO:gurobipy:Set parameter Username
# Academic license - for non-commercial use only - expires 2026-08-25
# INFO:gurobipy:Academic license - for non-commercial use only - expires 2026-08-25
# Read LP format model from file /tmp/linopy-problem-kdn38vqd.lp
# INFO:gurobipy:Read LP format model from file /tmp/linopy-problem-kdn38vqd.lp
# Reading time = 0.00 seconds
# INFO:gurobipy:Reading time = 0.00 seconds
# obj: 689 rows, 296 columns, 1332 nonzeros
# INFO:gurobipy:obj: 689 rows, 296 columns, 1332 nonzeros
# Set parameter Method to value 2
# INFO:gurobipy:Set parameter Method to value 2
# Set parameter Crossover to value 0
# INFO:gurobipy:Set parameter Crossover to value 0
# Set parameter LogToConsole to value 0
# INFO:gurobipy:Set parameter LogToConsole to value 0
# INFO:gurobipy:Gurobi Optimizer version 12.0.3 build v12.0.3rc0 (linux64 - "Linux Mint 22")
# INFO:gurobipy:
# INFO:gurobipy:CPU model: Intel(R) Core(TM) i7-10610U CPU @ 1.80GHz, instruction set [SSE2|AVX|AVX2]
# INFO:gurobipy:Thread count: 4 physical cores, 8 logical processors, using up to 8 threads
# INFO:gurobipy:
# INFO:gurobipy:Non-default parameters:
# INFO:gurobipy:Method  2
# INFO:gurobipy:Crossover  0
# INFO:gurobipy:LogToConsole  0
# INFO:gurobipy:
# INFO:gurobipy:Optimize a model with 689 rows, 296 columns and 1332 nonzeros
# INFO:gurobipy:Model fingerprint: 0x44d8b977
# INFO:gurobipy:Coefficient statistics:
# INFO:gurobipy:  Matrix range     [4e-02, 2e+03]
# INFO:gurobipy:  Objective range  [7e-03, 7e-01]
# INFO:gurobipy:  Bounds range     [0e+00, 0e+00]
# INFO:gurobipy:  RHS range        [2e+02, 7e+05]
# INFO:gurobipy:Presolve removed 124 rows and 334 columns
# INFO:gurobipy:Presolve time: 0.00s
# INFO:gurobipy:Presolved: 172 rows, 355 columns, 1578 nonzeros
# INFO:gurobipy:Ordering time: 0.00s
# INFO:gurobipy:
# INFO:gurobipy:Barrier statistics:
# INFO:gurobipy: Free vars  : 6
# INFO:gurobipy: AA' NZ     : 1.490e+03
# INFO:gurobipy: Factor NZ  : 3.248e+03
# INFO:gurobipy: Factor Ops : 6.994e+04 (less than 1 second per iteration)
# INFO:gurobipy: Threads    : 1
# INFO:gurobipy:
# INFO:gurobipy:                  Objective                Residual
# INFO:gurobipy:Iter       Primal          Dual         Primal    Dual     Compl     Time
# INFO:gurobipy:   0  -7.73669786e+03 -0.00000000e+00  9.01e-01 2.28e+02  3.17e+02     0s
# INFO:gurobipy:   1  -7.47952981e+03 -1.89860017e+03  3.95e-01 7.09e+02  8.83e+01     0s
# INFO:gurobipy:   2  -4.02512732e+03 -1.24040763e+03  4.93e-02 2.51e+02  2.98e+01     0s
# INFO:gurobipy:   3  -1.34694329e+03 -1.91712547e+02  2.23e-03 3.29e+01  4.99e+00     0s
# INFO:gurobipy:   4  -5.23961695e+02 -1.43739914e+02  1.94e-04 8.09e+00  1.32e+00     0s
# INFO:gurobipy:   5  -2.98625116e+02 -1.62965122e+02  3.66e-05 3.60e+00  4.80e-01     0s
# INFO:gurobipy:   6  -2.37566185e+02 -1.65562975e+02  1.59e-05 1.61e+00  2.33e-01     0s
# INFO:gurobipy:   7  -2.17102363e+02 -1.91273276e+02  4.37e-06 2.86e-01  6.84e-02     0s
# INFO:gurobipy:   8  -2.01793767e+02 -1.95507875e+02  6.53e-07 6.16e-02  1.62e-02     0s
# INFO:gurobipy:   9  -1.99040184e+02 -1.96990711e+02  1.65e-07 2.23e-02  5.39e-03     0s
# INFO:gurobipy:  10  -1.97889905e+02 -1.97626660e+02  2.03e-08 1.06e-03  5.84e-04     0s
# INFO:gurobipy:  11  -1.97708215e+02 -1.97696962e+02  6.00e-10 3.78e-05  2.46e-05     0s
# INFO:gurobipy:  12  -1.97703217e+02 -1.97703205e+02  9.13e-12 1.39e-10  2.45e-08     0s
# INFO:gurobipy:  13  -1.97703212e+02 -1.97703212e+02  1.26e-12 9.09e-13  1.96e-11     0s
# INFO:gurobipy:
# INFO:gurobipy:Barrier solved model in 13 iterations and 0.01 seconds (0.00 work units)
# INFO:gurobipy:Optimal objective -1.97703212e+02
# INFO:gurobipy:
# INFO:linopy.constants: Optimization successful:
# Status: ok
# Termination condition: optimal
# Solution: 296 primals, 689 duals
# Objective: -1.98e+02
# Solver: gurobi
# Runtime: 0.02s
# Dual bound: -1.98e+02
# Solver model: available
# Solver message: 2
#
# INFO:pypsa.optimization.optimize:The shadow-prices of the constraints Generator-ext-p-lower, Generator-ext-p-upper, Line-ext-s-lower, Line-ext-s-upper, StorageUnit-ext-p_dispatch-lower, StorageUnit-ext-p_dispatch-upper, StorageUnit-ext-p_store-lower, StorageUnit-ext-p_store-upper, StorageUnit-ext-state_of_charge-lower, StorageUnit-ext-state_of_charge-upper, StorageUnit-energy_balance, budget were not assigned to the network.

# %% [markdown]
# ### 3.3 Inspect the new alternatives

# %%
mga_total_capacities = pd.concat((
    pd.DataFrame(mga_alternatives[x]).fillna(0).round(2).sum(axis=1) for x in mga_alternatives
), axis=1)

mga_spatial_capacities = pd.concat((
    pd.DataFrame(mga_spatial_alternatives[x]).fillna(0).round(2).sum(axis=1) for x in mga_alternatives
), axis=1)

# %%
mga_total_capacities.plot.bar()
# Out:
# <Axes: >

# %%
mga_spatial_capacities.plot.bar()
# Out:
# <Axes: >

# %%
mga_weights = pd.concat((
    pd.DataFrame(mga_weights[x]).fillna(0).round(2).sum(axis=1) for x in mga_weights
), axis=1)
mga_weights
# Out:
#                 0    1     2     3     4     5
# OCGT          0.0  0.0  0.39  0.37  0.12 -0.22
# solar_bus1    0.0 -0.5 -0.38 -0.14 -0.58  0.02
# wind_bus1     0.0  0.5  0.58  0.49  0.65  0.49
# solar_bus2    0.0 -0.5 -0.20 -0.58  0.32 -0.52
# wind_bus2     0.0  0.5  0.58  0.49  0.28  0.67
# battery_bus1  0.0  0.0  0.00 -0.15  0.09 -0.01
# battery_bus2  0.0  0.0  0.05  0.08  0.21  0.02
