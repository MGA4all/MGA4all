# %% [markdown]
# # Tutorial: SPORES x PyPSA

# %%
import yaml
import pypsa

from mga4all.examples import create_pypsa_network

import pandas as pd

# %% [markdown]
# ## 1. Load example PyPSA model

# %%
# Load example PyPSA model that the config refers to
n = create_pypsa_network()
# Out:
# INFO:pypsa.network.io:Imported network 'SciGrid-DE' has buses, carriers, generators, lines, loads, storage_units, transformers

# %%
# Set the desired solver options
pypsa.options.params.optimize.solver_name = "gurobi"
pypsa.options.params.optimize.solver_options = {
    'Method': 2,  # Use the barrier algorithm
    'Crossover': 0,
}

# %%
# Find cost-optimal solution
n.optimize(log_to_console=False);
# Out:
# /tmp/ipykernel_105570/2238090962.py:2: FutureWarning: The default value of `include_objective_constant` will change from True to False in version 2.0. Set `include_objective_constant` explicitly to suppress this warning. Using False improves LP numerical conditioning by not including the objective constant as a variable.
#   n.optimize(log_to_console=False);
# WARNING:pypsa.consistency:The following lines have zero x, which could break the linear load flow:
# Index(['line'], dtype='object', name='name')
# WARNING:pypsa.consistency:The following lines have zero r, which could break the linear load flow:
# Index(['line'], dtype='object', name='name')
# INFO:linopy.model: Solve problem using Gurobi solver
# INFO:linopy.model:Solver options:
#  - Method: 2
#  - Crossover: 0
#  - log_to_console: False
# INFO:linopy.io: Writing time: 0.06s
# Set parameter Username
# INFO:gurobipy:Set parameter Username
# Academic license - for non-commercial use only - expires 2026-08-25
# INFO:gurobipy:Academic license - for non-commercial use only - expires 2026-08-25
# Read LP format model from file /tmp/linopy-problem-c5xa0t66.lp
# INFO:gurobipy:Read LP format model from file /tmp/linopy-problem-c5xa0t66.lp
# Reading time = 0.00 seconds
# INFO:gurobipy:Reading time = 0.00 seconds
# obj: 688 rows, 296 columns, 1324 nonzeros
# INFO:gurobipy:obj: 688 rows, 296 columns, 1324 nonzeros
# Set parameter Method to value 2
# INFO:gurobipy:Set parameter Method to value 2
# Set parameter Crossover to value 0
# INFO:gurobipy:Set parameter Crossover to value 0
# Set parameter LogToConsole to value 0
# INFO:gurobipy:Set parameter LogToConsole to value 0
# INFO:gurobipy:Gurobi Optimizer version 12.0.3 build v12.0.3rc0 (linux64 - "Linux Mint 22")
# INFO:gurobipy:
# INFO:gurobipy:CPU model: Intel(R) Core(TM) i7-10610U CPU @ 1.80GHz, instruction set [SSE2|AVX|AVX2]
# INFO:gurobipy:Thread count: 4 physical cores, 8 logical processors, using up to 8 threads
# INFO:gurobipy:
# INFO:gurobipy:Non-default parameters:
# INFO:gurobipy:Method  2
# INFO:gurobipy:Crossover  0
# INFO:gurobipy:LogToConsole  0
# INFO:gurobipy:
# INFO:gurobipy:Optimize a model with 688 rows, 296 columns and 1324 nonzeros
# INFO:gurobipy:Model fingerprint: 0xd41ae2e6
# INFO:gurobipy:Coefficient statistics:
# INFO:gurobipy:  Matrix range     [4e-02, 5e+00]
# INFO:gurobipy:  Objective range  [4e+02, 2e+03]
# INFO:gurobipy:  Bounds range     [0e+00, 0e+00]
# INFO:gurobipy:  RHS range        [2e+02, 1e+03]
# INFO:gurobipy:Presolve removed 124 rows and 332 columns
# INFO:gurobipy:Presolve time: 0.00s
# INFO:gurobipy:Presolved: 172 rows, 356 columns, 1572 nonzeros
# INFO:gurobipy:Ordering time: 0.00s
# INFO:gurobipy:
# INFO:gurobipy:Barrier statistics:
# INFO:gurobipy: Free vars  : 6
# INFO:gurobipy: AA' NZ     : 1.462e+03
# INFO:gurobipy: Factor NZ  : 3.702e+03
# INFO:gurobipy: Factor Ops : 8.857e+04 (less than 1 second per iteration)
# INFO:gurobipy: Threads    : 1
# INFO:gurobipy:
# INFO:gurobipy:                  Objective                Residual
# INFO:gurobipy:Iter       Primal          Dual         Primal    Dual     Compl     Time
# INFO:gurobipy:   0  -1.00409619e+07  1.26434985e+06  5.02e+04 2.32e+02  8.08e+05     0s
# INFO:gurobipy:   1  -1.62363797e+07  3.83761269e+06  1.05e+04 1.29e+02  2.23e+05     0s
# INFO:gurobipy:   2  -1.19102174e+07  3.48788782e+06  3.62e+02 2.51e-04  3.20e+04     0s
# INFO:gurobipy:   3  -2.57093358e+06  1.77942311e+06  9.73e+01 3.18e-04  8.90e+03     0s
# INFO:gurobipy:   4  -2.27818582e+04  1.28001349e+06  1.28e+01 1.34e-04  2.59e+03     0s
# INFO:gurobipy:   5   2.15322037e+05  1.03328648e+06  8.76e+00 6.29e-05  1.62e+03     0s
# INFO:gurobipy:   6  -1.20186200e+05  8.65093190e+05  2.34e+00 5.33e-05  1.92e+03     0s
# INFO:gurobipy:   7   4.63414619e+05  7.17305096e+05  3.85e-01 2.15e-05  4.94e+02     0s
# INFO:gurobipy:   8   5.78794372e+05  6.53916444e+05  8.15e-02 1.62e-05  1.46e+02     0s
# INFO:gurobipy:   9   6.03297884e+05  6.24674068e+05  2.14e-02 7.14e-06  4.15e+01     0s
# INFO:gurobipy:  10   6.14810979e+05  6.19552578e+05  8.25e-04 8.53e-05  9.21e+00     0s
# INFO:gurobipy:  11   6.15517016e+05  6.15556729e+05  6.88e-07 4.45e-06  7.71e-02     0s
# INFO:gurobipy:  12   6.15519375e+05  6.15519415e+05  4.71e-09 4.03e-08  7.71e-05     0s
# INFO:gurobipy:  13   6.15519377e+05  6.15519377e+05  2.43e-09 3.58e-11  2.54e-10     0s
# INFO:gurobipy:
# INFO:gurobipy:Barrier solved model in 13 iterations and 0.02 seconds (0.00 work units)
# INFO:gurobipy:Optimal objective 6.15519377e+05
# INFO:gurobipy:
# INFO:linopy.constants: Optimization successful:
# Status: ok
# Termination condition: optimal
# Solution: 296 primals, 688 duals
# Objective: 6.16e+05
# Solver: gurobi
# Runtime: 0.02s
# Dual bound: 6.16e+05
# Solver model: available
# Solver message: 2
#
# INFO:pypsa.optimization.optimize:The shadow-prices of the constraints Generator-ext-p-lower, Generator-ext-p-upper, Line-ext-s-lower, Line-ext-s-upper, StorageUnit-ext-p_dispatch-lower, StorageUnit-ext-p_dispatch-upper, StorageUnit-ext-p_store-lower, StorageUnit-ext-p_store-upper, StorageUnit-ext-state_of_charge-lower, StorageUnit-ext-state_of_charge-upper, StorageUnit-energy_balance were not assigned to the network.

# %% [markdown]
# ## 2. Generate alternative solutions with SPORES MGA (simple diversificaton)

# %% [markdown]
# ### 2.1 Load and check MGA configuration

# %%
from mga4all.validate import SPORESConfig

# Load configuration file
with open("../../configs/test_config_spores_diversify_only.yaml") as yf:
    test_config = SPORESConfig.model_validate(yaml.safe_load(yf))

# %%
# Check that it reflects the desired setup
test_config
# Out:
# {'config_name': 'spores',
#  'model_interface': 'pypsa',
#  'cost_slack': 0.1,
#  'alternatives': 5,
#  'spatially_explicit': True,
#  'diversification_coefficient': 'auto',
#  'intensification_coefficient': 0,
#  'diversified_technologies': ['wind', 'solar', 'gas', 'battery'],
#  'intensified_technologies': []}

# %% [markdown]
# ### 2.2 Import algorithm and run

# %%
from mga4all.mga_spores import spores_algorithm

# %%
mga_alternatives, mga_spatial_alternatives, mga_weights = spores_algorithm(test_config, n)
# Out:
# WARNING:pypsa.consistency:Encountered nan's in varying data 'v_ang' for columns ['bus1', 'bus2'] of component 'Bus'.
# WARNING:pypsa.consistency:The following lines have zero x, which could break the linear load flow:
# Index(['line'], dtype='object', name='name')
# WARNING:pypsa.consistency:The following lines have zero r, which could break the linear load flow:
# Index(['line'], dtype='object', name='name')
# INFO:linopy.model: Solve problem using Gurobi solver
# INFO:linopy.model:Solver options:
#  - Method: 2
#  - Crossover: 0
#  - log_to_console: False
# INFO:linopy.io: Writing time: 0.06s
# Technologies [] not found in the model
# Set parameter Username
# INFO:gurobipy:Set parameter Username
# Academic license - for non-commercial use only - expires 2026-08-25
# INFO:gurobipy:Academic license - for non-commercial use only - expires 2026-08-25
# Read LP format model from file /tmp/linopy-problem-2aaupv85.lp
# INFO:gurobipy:Read LP format model from file /tmp/linopy-problem-2aaupv85.lp
# Reading time = 0.00 seconds
# INFO:gurobipy:Reading time = 0.00 seconds
# obj: 689 rows, 296 columns, 1332 nonzeros
# INFO:gurobipy:obj: 689 rows, 296 columns, 1332 nonzeros
# Set parameter Method to value 2
# INFO:gurobipy:Set parameter Method to value 2
# Set parameter Crossover to value 0
# INFO:gurobipy:Set parameter Crossover to value 0
# Set parameter LogToConsole to value 0
# INFO:gurobipy:Set parameter LogToConsole to value 0
# INFO:gurobipy:Gurobi Optimizer version 12.0.3 build v12.0.3rc0 (linux64 - "Linux Mint 22")
# INFO:gurobipy:
# INFO:gurobipy:CPU model: Intel(R) Core(TM) i7-10610U CPU @ 1.80GHz, instruction set [SSE2|AVX|AVX2]
# INFO:gurobipy:Thread count: 4 physical cores, 8 logical processors, using up to 8 threads
# INFO:gurobipy:
# INFO:gurobipy:Non-default parameters:
# INFO:gurobipy:Method  2
# INFO:gurobipy:Crossover  0
# INFO:gurobipy:LogToConsole  0
# INFO:gurobipy:
# INFO:gurobipy:Optimize a model with 689 rows, 296 columns and 1332 nonzeros
# INFO:gurobipy:Model fingerprint: 0x6a5b942b
# INFO:gurobipy:Coefficient statistics:
# INFO:gurobipy:  Matrix range     [4e-02, 2e+03]
# INFO:gurobipy:  Objective range  [4e-15, 9e-01]
# INFO:gurobipy:  Bounds range     [0e+00, 0e+00]
# INFO:gurobipy:  RHS range        [2e+02, 7e+05]
# INFO:gurobipy:Presolve removed 124 rows and 334 columns
# INFO:gurobipy:Presolve time: 0.00s
# INFO:gurobipy:Presolved: 172 rows, 355 columns, 1578 nonzeros
# INFO:gurobipy:Ordering time: 0.00s
# INFO:gurobipy:
# INFO:gurobipy:Barrier statistics:
# INFO:gurobipy: Free vars  : 6
# INFO:gurobipy: AA' NZ     : 1.490e+03
# INFO:gurobipy: Factor NZ  : 3.248e+03
# INFO:gurobipy: Factor Ops : 6.994e+04 (less than 1 second per iteration)
# INFO:gurobipy: Threads    : 1
# INFO:gurobipy:
# INFO:gurobipy:                  Objective                Residual
# INFO:gurobipy:Iter       Primal          Dual         Primal    Dual     Compl     Time
# INFO:gurobipy:   0  -9.88714866e+03 -0.00000000e+00  1.16e+00 2.28e+02  4.07e+02     0s
# INFO:gurobipy:   1  -9.42183212e+03 -1.69711491e+03  4.92e-01 7.16e+02  1.14e+02     0s
# INFO:gurobipy:   2  -4.39482390e+03 -3.40648809e+02  2.93e-02 2.15e+02  3.20e+01     0s
# INFO:gurobipy:   3  -9.26068071e+02  9.20027927e+01  1.64e-03 3.31e+01  5.14e+00     0s
# INFO:gurobipy:   4  -3.74801456e+02  6.50215202e+01  2.79e-04 4.54e+00  1.24e+00     0s
# INFO:gurobipy:   5  -1.08379520e+02  2.54383440e+01  5.15e-05 1.26e+00  3.24e-01     0s
# INFO:gurobipy:   6  -6.05545454e+01  1.95679392e+01  2.93e-05 3.14e-02  1.58e-01     0s
# INFO:gurobipy:   7  -9.90631660e+00  1.67854584e+01  8.72e-06 7.67e-03  5.23e-02     0s
# INFO:gurobipy:   8  -8.96240434e-01  1.29013617e+01  4.74e-06 5.08e-08  2.70e-02     0s
# INFO:gurobipy:   9   7.13287081e+00  1.06008149e+01  1.08e-06 2.28e-08  6.77e-03     0s
# INFO:gurobipy:  10   9.58464408e+00  9.81707394e+00  2.63e-08 4.60e-09  4.53e-04     0s
# INFO:gurobipy:  11   9.69019976e+00  9.70695258e+00  4.24e-09 6.90e-10  3.27e-05     0s
# INFO:gurobipy:  12   9.69196840e+00  9.69208755e+00  3.45e-10 2.25e-11  2.32e-07     0s
# INFO:gurobipy:  13   9.69201647e+00  9.69201656e+00  3.06e-12 1.82e-12  1.62e-10     0s
# INFO:gurobipy:
# INFO:gurobipy:Barrier solved model in 13 iterations and 0.01 seconds (0.00 work units)
# INFO:gurobipy:Optimal objective 9.69201647e+00
# INFO:gurobipy:
# INFO:linopy.constants: Optimization successful:
# Status: ok
# Termination condition: optimal
# Solution: 296 primals, 689 duals
# Objective: 9.69e+00
# Solver: gurobi
# Runtime: 0.01s
# Dual bound: 9.69e+00
# Solver model: available
# Solver message: 2
#
# INFO:pypsa.optimization.optimize:The shadow-prices of the constraints Generator-ext-p-lower, Generator-ext-p-upper, Line-ext-s-lower, Line-ext-s-upper, StorageUnit-ext-p_dispatch-lower, StorageUnit-ext-p_dispatch-upper, StorageUnit-ext-p_store-lower, StorageUnit-ext-p_store-upper, StorageUnit-ext-state_of_charge-lower, StorageUnit-ext-state_of_charge-upper, StorageUnit-energy_balance, budget were not assigned to the network.
# INFO:linopy.model: Solve problem using Gurobi solver
# INFO:linopy.model:Solver options:
#  - Method: 2
#  - Crossover: 0
#  - log_to_console: False
# INFO:linopy.io: Writing time: 0.05s
# Set parameter Username
# INFO:gurobipy:Set parameter Username
# Academic license - for non-commercial use only - expires 2026-08-25
# INFO:gurobipy:Academic license - for non-commercial use only - expires 2026-08-25
# Read LP format model from file /tmp/linopy-problem-jk7oet9a.lp
# INFO:gurobipy:Read LP format model from file /tmp/linopy-problem-jk7oet9a.lp
# Reading time = 0.00 seconds
# INFO:gurobipy:Reading time = 0.00 seconds
# obj: 689 rows, 296 columns, 1332 nonzeros
# INFO:gurobipy:obj: 689 rows, 296 columns, 1332 nonzeros
# Set parameter Method to value 2
# INFO:gurobipy:Set parameter Method to value 2
# Set parameter Crossover to value 0
# INFO:gurobipy:Set parameter Crossover to value 0
# Set parameter LogToConsole to value 0
# INFO:gurobipy:Set parameter LogToConsole to value 0
# INFO:gurobipy:Gurobi Optimizer version 12.0.3 build v12.0.3rc0 (linux64 - "Linux Mint 22")
# INFO:gurobipy:
# INFO:gurobipy:CPU model: Intel(R) Core(TM) i7-10610U CPU @ 1.80GHz, instruction set [SSE2|AVX|AVX2]
# INFO:gurobipy:Thread count: 4 physical cores, 8 logical processors, using up to 8 threads
# INFO:gurobipy:
# INFO:gurobipy:Non-default parameters:
# INFO:gurobipy:Method  2
# INFO:gurobipy:Crossover  0
# INFO:gurobipy:LogToConsole  0
# INFO:gurobipy:
# INFO:gurobipy:Optimize a model with 689 rows, 296 columns and 1332 nonzeros
# INFO:gurobipy:Model fingerprint: 0xf83f1aae
# INFO:gurobipy:Coefficient statistics:
# INFO:gurobipy:  Matrix range     [4e-02, 2e+03]
# INFO:gurobipy:  Objective range  [5e-11, 7e-01]
# INFO:gurobipy:  Bounds range     [0e+00, 0e+00]
# INFO:gurobipy:  RHS range        [2e+02, 7e+05]
# INFO:gurobipy:Presolve removed 124 rows and 334 columns
# INFO:gurobipy:Presolve time: 0.00s
# INFO:gurobipy:Presolved: 172 rows, 355 columns, 1578 nonzeros
# INFO:gurobipy:Ordering time: 0.00s
# INFO:gurobipy:
# INFO:gurobipy:Barrier statistics:
# INFO:gurobipy: Free vars  : 6
# INFO:gurobipy: AA' NZ     : 1.490e+03
# INFO:gurobipy: Factor NZ  : 3.248e+03
# INFO:gurobipy: Factor Ops : 6.994e+04 (less than 1 second per iteration)
# INFO:gurobipy: Threads    : 1
# INFO:gurobipy:
# INFO:gurobipy:                  Objective                Residual
# INFO:gurobipy:Iter       Primal          Dual         Primal    Dual     Compl     Time
# INFO:gurobipy:   0  -8.15057275e+03 -0.00000000e+00  9.01e-01 2.28e+02  3.18e+02     0s
# INFO:gurobipy:   1  -7.64883724e+03 -7.18525989e+02  3.05e-01 5.48e+02  7.24e+01     0s
# INFO:gurobipy:   2  -5.11865269e+03 -2.35668445e+01  1.13e-01 1.68e+02  2.89e+01     0s
# INFO:gurobipy:   3  -1.68483931e+03  9.51211223e+01  3.44e-03 2.40e+01  5.38e+00     0s
# INFO:gurobipy:   4  -4.13994526e+02  7.13499072e+01  6.57e-04 6.91e+00  1.39e+00     0s
# INFO:gurobipy:   5  -7.63504849e+01  4.84902407e+01  9.11e-05 1.74e+00  3.04e-01     0s
# INFO:gurobipy:   6  -1.98915107e+01  1.59997897e+01  2.66e-05 5.64e-02  7.21e-02     0s
# INFO:gurobipy:   7  -7.64183535e+00  4.75380645e+00  1.16e-05 1.28e-03  2.43e-02     0s
# INFO:gurobipy:   8  -1.76957803e+00  5.09233830e-01  1.96e-06 1.36e-08  4.46e-03     0s
# INFO:gurobipy:   9  -5.14186861e-02  5.35643612e-02  7.24e-08 5.53e-09  2.05e-04     0s
# INFO:gurobipy:  10  -5.26849390e-05  5.50113394e-05  3.20e-10 6.00e-11  2.09e-07     0s
# INFO:gurobipy:  11  -7.97513672e-07  3.73921978e-07  5.14e-10 1.25e-12  2.46e-09     0s
# INFO:gurobipy:  12  -9.49452813e-08  2.55511482e-07  1.21e-09 1.27e-11  3.99e-10     0s
# INFO:gurobipy:  13   3.49254661e-07  2.48234139e-07  2.15e-09 1.04e-10  2.69e-11     0s
# INFO:gurobipy:  14  -2.44326766e-06  2.48381062e-07  2.32e-08 1.07e-10  1.05e-12     0s
# INFO:gurobipy:
# INFO:gurobipy:Barrier solved model in 14 iterations and 0.01 seconds (0.00 work units)
# INFO:gurobipy:Optimal objective -2.44326766e-06
# INFO:gurobipy:
# INFO:linopy.constants: Optimization successful:
# Status: ok
# Termination condition: optimal
# Solution: 296 primals, 689 duals
# Objective: 2.48e-07
# Solver: gurobi
# Runtime: 0.02s
# Dual bound: 2.48e-07
# Solver model: available
# Solver message: 2
#
# INFO:pypsa.optimization.optimize:The shadow-prices of the constraints Generator-ext-p-lower, Generator-ext-p-upper, Line-ext-s-lower, Line-ext-s-upper, StorageUnit-ext-p_dispatch-lower, StorageUnit-ext-p_dispatch-upper, StorageUnit-ext-p_store-lower, StorageUnit-ext-p_store-upper, StorageUnit-ext-state_of_charge-lower, StorageUnit-ext-state_of_charge-upper, StorageUnit-energy_balance, budget were not assigned to the network.
# INFO:linopy.model: Solve problem using Gurobi solver
# INFO:linopy.model:Solver options:
#  - Method: 2
#  - Crossover: 0
#  - log_to_console: False
# INFO:linopy.io: Writing time: 0.07s
# Set parameter Username
# INFO:gurobipy:Set parameter Username
# Academic license - for non-commercial use only - expires 2026-08-25
# INFO:gurobipy:Academic license - for non-commercial use only - expires 2026-08-25
# Read LP format model from file /tmp/linopy-problem-ynj7j0ez.lp
# INFO:gurobipy:Read LP format model from file /tmp/linopy-problem-ynj7j0ez.lp
# Reading time = 0.00 seconds
# INFO:gurobipy:Reading time = 0.00 seconds
# obj: 689 rows, 296 columns, 1332 nonzeros
# INFO:gurobipy:obj: 689 rows, 296 columns, 1332 nonzeros
# Set parameter Method to value 2
# INFO:gurobipy:Set parameter Method to value 2
# Set parameter Crossover to value 0
# INFO:gurobipy:Set parameter Crossover to value 0
# Set parameter LogToConsole to value 0
# INFO:gurobipy:Set parameter LogToConsole to value 0
# INFO:gurobipy:Gurobi Optimizer version 12.0.3 build v12.0.3rc0 (linux64 - "Linux Mint 22")
# INFO:gurobipy:
# INFO:gurobipy:CPU model: Intel(R) Core(TM) i7-10610U CPU @ 1.80GHz, instruction set [SSE2|AVX|AVX2]
# INFO:gurobipy:Thread count: 4 physical cores, 8 logical processors, using up to 8 threads
# INFO:gurobipy:
# INFO:gurobipy:Non-default parameters:
# INFO:gurobipy:Method  2
# INFO:gurobipy:Crossover  0
# INFO:gurobipy:LogToConsole  0
# INFO:gurobipy:
# INFO:gurobipy:Optimize a model with 689 rows, 296 columns and 1332 nonzeros
# INFO:gurobipy:Model fingerprint: 0x56691a34
# INFO:gurobipy:Coefficient statistics:
# INFO:gurobipy:  Matrix range     [4e-02, 2e+03]
# INFO:gurobipy:  Objective range  [4e-14, 1e+00]
# INFO:gurobipy:  Bounds range     [0e+00, 0e+00]
# INFO:gurobipy:  RHS range        [2e+02, 7e+05]
# INFO:gurobipy:Presolve removed 124 rows and 334 columns
# INFO:gurobipy:Presolve time: 0.00s
# INFO:gurobipy:Presolved: 172 rows, 355 columns, 1578 nonzeros
# INFO:gurobipy:Ordering time: 0.00s
# INFO:gurobipy:
# INFO:gurobipy:Barrier statistics:
# INFO:gurobipy: Free vars  : 6
# INFO:gurobipy: AA' NZ     : 1.490e+03
# INFO:gurobipy: Factor NZ  : 3.248e+03
# INFO:gurobipy: Factor Ops : 6.994e+04 (less than 1 second per iteration)
# INFO:gurobipy: Threads    : 1
# INFO:gurobipy:
# INFO:gurobipy:                  Objective                Residual
# INFO:gurobipy:Iter       Primal          Dual         Primal    Dual     Compl     Time
# INFO:gurobipy:   0  -1.00391649e+04 -0.00000000e+00  1.18e+00 2.28e+02  4.16e+02     0s
# INFO:gurobipy:   1  -9.57294493e+03 -1.74258312e+03  5.05e-01 7.14e+02  1.17e+02     0s
# INFO:gurobipy:   2  -4.36270185e+03 -4.12629121e+02  1.17e-02 2.17e+02  3.19e+01     0s
# INFO:gurobipy:   3  -8.36896881e+02  5.39665262e+01  5.49e-04 3.67e+01  5.18e+00     0s
# INFO:gurobipy:   4  -2.28349893e+02  3.95889700e+01  2.91e-05 2.47e+00  7.24e-01     0s
# INFO:gurobipy:   5  -7.14534096e+01  1.28658898e+01  5.08e-06 6.87e-01  1.93e-01     0s
# INFO:gurobipy:   6  -3.02150764e+01  8.73350266e+00  2.20e-06 1.66e-01  8.17e-02     0s
# INFO:gurobipy:   7  -7.98758093e+00  3.74905361e+00  5.75e-07 2.95e-02  2.36e-02     0s
# INFO:gurobipy:   8  -1.69217787e+00  8.55381666e-01  8.32e-08 1.45e-04  5.07e-03     0s
# INFO:gurobipy:   9  -5.33460108e-01  1.52580613e-01  2.66e-08 5.30e-09  1.35e-03     0s
# INFO:gurobipy:  10  -3.24544842e-03  1.39260168e-02  1.02e-09 1.43e-09  3.46e-05     0s
# INFO:gurobipy:  11  -2.26898647e-07  1.24584591e-07  1.37e-10 5.11e-12  6.92e-10     0s
# INFO:gurobipy:  12  -2.12461873e-10  1.60086064e-10  1.81e-13 1.82e-12  6.90e-13     0s
# INFO:gurobipy:
# INFO:gurobipy:Barrier solved model in 12 iterations and 0.02 seconds (0.00 work units)
# INFO:gurobipy:Optimal objective -2.12461873e-10
# INFO:gurobipy:
# INFO:linopy.constants: Optimization successful:
# Status: ok
# Termination condition: optimal
# Solution: 296 primals, 689 duals
# Objective: 1.60e-10
# Solver: gurobi
# Runtime: 0.02s
# Dual bound: 1.60e-10
# Solver model: available
# Solver message: 2
#
# INFO:pypsa.optimization.optimize:The shadow-prices of the constraints Generator-ext-p-lower, Generator-ext-p-upper, Line-ext-s-lower, Line-ext-s-upper, StorageUnit-ext-p_dispatch-lower, StorageUnit-ext-p_dispatch-upper, StorageUnit-ext-p_store-lower, StorageUnit-ext-p_store-upper, StorageUnit-ext-state_of_charge-lower, StorageUnit-ext-state_of_charge-upper, StorageUnit-energy_balance, budget were not assigned to the network.
# INFO:linopy.model: Solve problem using Gurobi solver
# INFO:linopy.model:Solver options:
#  - Method: 2
#  - Crossover: 0
#  - log_to_console: False
# INFO:linopy.io: Writing time: 0.05s
# Set parameter Username
# INFO:gurobipy:Set parameter Username
# Academic license - for non-commercial use only - expires 2026-08-25
# INFO:gurobipy:Academic license - for non-commercial use only - expires 2026-08-25
# Read LP format model from file /tmp/linopy-problem-hljkykod.lp
# INFO:gurobipy:Read LP format model from file /tmp/linopy-problem-hljkykod.lp
# Reading time = 0.00 seconds
# INFO:gurobipy:Reading time = 0.00 seconds
# obj: 689 rows, 296 columns, 1332 nonzeros
# INFO:gurobipy:obj: 689 rows, 296 columns, 1332 nonzeros
# Set parameter Method to value 2
# INFO:gurobipy:Set parameter Method to value 2
# Set parameter Crossover to value 0
# INFO:gurobipy:Set parameter Crossover to value 0
# Set parameter LogToConsole to value 0
# INFO:gurobipy:Set parameter LogToConsole to value 0
# INFO:gurobipy:Gurobi Optimizer version 12.0.3 build v12.0.3rc0 (linux64 - "Linux Mint 22")
# INFO:gurobipy:
# INFO:gurobipy:CPU model: Intel(R) Core(TM) i7-10610U CPU @ 1.80GHz, instruction set [SSE2|AVX|AVX2]
# INFO:gurobipy:Thread count: 4 physical cores, 8 logical processors, using up to 8 threads
# INFO:gurobipy:
# INFO:gurobipy:Non-default parameters:
# INFO:gurobipy:Method  2
# INFO:gurobipy:Crossover  0
# INFO:gurobipy:LogToConsole  0
# INFO:gurobipy:
# INFO:gurobipy:Optimize a model with 689 rows, 296 columns and 1332 nonzeros
# INFO:gurobipy:Model fingerprint: 0x3098a669
# INFO:gurobipy:Coefficient statistics:
# INFO:gurobipy:  Matrix range     [4e-02, 2e+03]
# INFO:gurobipy:  Objective range  [8e-14, 8e-01]
# INFO:gurobipy:  Bounds range     [0e+00, 0e+00]
# INFO:gurobipy:  RHS range        [2e+02, 7e+05]
# INFO:gurobipy:Presolve removed 124 rows and 334 columns
# INFO:gurobipy:Presolve time: 0.00s
# INFO:gurobipy:Presolved: 172 rows, 355 columns, 1578 nonzeros
# INFO:gurobipy:Ordering time: 0.00s
# INFO:gurobipy:
# INFO:gurobipy:Barrier statistics:
# INFO:gurobipy: Free vars  : 6
# INFO:gurobipy: AA' NZ     : 1.490e+03
# INFO:gurobipy: Factor NZ  : 3.248e+03
# INFO:gurobipy: Factor Ops : 6.994e+04 (less than 1 second per iteration)
# INFO:gurobipy: Threads    : 1
# INFO:gurobipy:
# INFO:gurobipy:                  Objective                Residual
# INFO:gurobipy:Iter       Primal          Dual         Primal    Dual     Compl     Time
# INFO:gurobipy:   0  -8.41610190e+03 -0.00000000e+00  9.01e-01 2.28e+02  3.20e+02     0s
# INFO:gurobipy:   1  -7.84177448e+03 -4.15368862e+02  2.53e-01 5.61e+02  7.24e+01     0s
# INFO:gurobipy:   2  -4.36140413e+03  6.86381932e+01  4.05e-02 1.70e+02  2.49e+01     0s
# INFO:gurobipy:   3  -1.16650904e+03  1.14866731e+02  1.05e-03 2.16e+01  3.98e+00     0s
# INFO:gurobipy:   4  -3.41834357e+02  7.19996103e+01  1.78e-04 4.00e+00  1.04e+00     0s
# INFO:gurobipy:   5  -1.21738330e+02  4.06614415e+01  6.10e-05 7.32e-01  3.54e-01     0s
# INFO:gurobipy:   6  -3.30871642e+01  1.72748474e+01  1.77e-05 1.36e-07  9.96e-02     0s
# INFO:gurobipy:   7  -1.50061304e+01  6.53901113e+00  7.78e-06 4.87e-08  4.21e-02     0s
# INFO:gurobipy:   8  -6.03165497e+00  7.86411865e-01  2.66e-06 1.85e-08  1.33e-02     0s
# INFO:gurobipy:   9  -2.60802942e-01  2.68866695e-01  1.20e-07 1.29e-08  1.03e-03     0s
# INFO:gurobipy:  10  -1.18505664e-03  1.57714161e-03  1.36e-09 4.97e-10  5.38e-06     0s
# INFO:gurobipy:  11  -2.97600001e-07  1.08020026e-07  2.22e-11 1.82e-12  7.67e-10     0s
# INFO:gurobipy:  12   1.46812741e-09  7.23292904e-10  7.35e-12 6.80e-13  9.78e-13     0s
# INFO:gurobipy:
# INFO:gurobipy:Barrier solved model in 12 iterations and 0.01 seconds (0.00 work units)
# INFO:gurobipy:Optimal objective 1.46812741e-09
# INFO:gurobipy:
# INFO:linopy.constants: Optimization successful:
# Status: ok
# Termination condition: optimal
# Solution: 296 primals, 689 duals
# Objective: 7.23e-10
# Solver: gurobi
# Runtime: 0.01s
# Dual bound: 7.23e-10
# Solver model: available
# Solver message: 2
#
# INFO:pypsa.optimization.optimize:The shadow-prices of the constraints Generator-ext-p-lower, Generator-ext-p-upper, Line-ext-s-lower, Line-ext-s-upper, StorageUnit-ext-p_dispatch-lower, StorageUnit-ext-p_dispatch-upper, StorageUnit-ext-p_store-lower, StorageUnit-ext-p_store-upper, StorageUnit-ext-state_of_charge-lower, StorageUnit-ext-state_of_charge-upper, StorageUnit-energy_balance, budget were not assigned to the network.
# INFO:linopy.model: Solve problem using Gurobi solver
# INFO:linopy.model:Solver options:
#  - Method: 2
#  - Crossover: 0
#  - log_to_console: False
# INFO:linopy.io: Writing time: 0.06s
# Set parameter Username
# INFO:gurobipy:Set parameter Username
# Academic license - for non-commercial use only - expires 2026-08-25
# INFO:gurobipy:Academic license - for non-commercial use only - expires 2026-08-25
# Read LP format model from file /tmp/linopy-problem-xd9wdh_m.lp
# INFO:gurobipy:Read LP format model from file /tmp/linopy-problem-xd9wdh_m.lp
# Reading time = 0.00 seconds
# INFO:gurobipy:Reading time = 0.00 seconds
# obj: 689 rows, 296 columns, 1332 nonzeros
# INFO:gurobipy:obj: 689 rows, 296 columns, 1332 nonzeros
# Set parameter Method to value 2
# INFO:gurobipy:Set parameter Method to value 2
# Set parameter Crossover to value 0
# INFO:gurobipy:Set parameter Crossover to value 0
# Set parameter LogToConsole to value 0
# INFO:gurobipy:Set parameter LogToConsole to value 0
# INFO:gurobipy:Gurobi Optimizer version 12.0.3 build v12.0.3rc0 (linux64 - "Linux Mint 22")
# INFO:gurobipy:
# INFO:gurobipy:CPU model: Intel(R) Core(TM) i7-10610U CPU @ 1.80GHz, instruction set [SSE2|AVX|AVX2]
# INFO:gurobipy:Thread count: 4 physical cores, 8 logical processors, using up to 8 threads
# INFO:gurobipy:
# INFO:gurobipy:Non-default parameters:
# INFO:gurobipy:Method  2
# INFO:gurobipy:Crossover  0
# INFO:gurobipy:LogToConsole  0
# INFO:gurobipy:
# INFO:gurobipy:Optimize a model with 689 rows, 296 columns and 1332 nonzeros
# INFO:gurobipy:Model fingerprint: 0x5b2214b2
# INFO:gurobipy:Coefficient statistics:
# INFO:gurobipy:  Matrix range     [4e-02, 2e+03]
# INFO:gurobipy:  Objective range  [2e-14, 1e+00]
# INFO:gurobipy:  Bounds range     [0e+00, 0e+00]
# INFO:gurobipy:  RHS range        [2e+02, 7e+05]
# INFO:gurobipy:Presolve removed 124 rows and 334 columns
# INFO:gurobipy:Presolve time: 0.00s
# INFO:gurobipy:Presolved: 172 rows, 355 columns, 1578 nonzeros
# INFO:gurobipy:Ordering time: 0.00s
# INFO:gurobipy:
# INFO:gurobipy:Barrier statistics:
# INFO:gurobipy: Free vars  : 6
# INFO:gurobipy: AA' NZ     : 1.490e+03
# INFO:gurobipy: Factor NZ  : 3.248e+03
# INFO:gurobipy: Factor Ops : 6.994e+04 (less than 1 second per iteration)
# INFO:gurobipy: Threads    : 1
# INFO:gurobipy:
# INFO:gurobipy:                  Objective                Residual
# INFO:gurobipy:Iter       Primal          Dual         Primal    Dual     Compl     Time
# INFO:gurobipy:   0  -1.00424086e+04 -0.00000000e+00  1.19e+00 2.28e+02  4.16e+02     0s
# INFO:gurobipy:   1  -9.57741088e+03 -1.74810967e+03  5.06e-01 7.13e+02  1.17e+02     0s
# INFO:gurobipy:   2  -4.34748356e+03 -4.23057563e+02  9.09e-03 2.18e+02  3.19e+01     0s
# INFO:gurobipy:   3  -8.31394767e+02  4.66014162e+01  4.40e-04 3.86e+01  5.31e+00     0s
# INFO:gurobipy:   4  -2.29599516e+02  3.98079605e+01  2.37e-05 3.19e+00  7.82e-01     0s
# INFO:gurobipy:   5  -6.43177432e+01  1.63213065e+01  2.29e-06 5.72e-01  1.81e-01     0s
# INFO:gurobipy:   6  -3.04529686e+01  8.99175216e+00  1.13e-06 1.17e-01  8.06e-02     0s
# INFO:gurobipy:   7  -8.42811073e+00  3.90850507e+00  3.13e-07 7.16e-08  2.45e-02     0s
# INFO:gurobipy:   8  -1.38603596e+00  7.26942343e-01  2.85e-08 1.94e-08  4.17e-03     0s
# INFO:gurobipy:   9  -3.22962620e-01  1.95349465e-01  5.81e-09 6.21e-09  1.02e-03     0s
# INFO:gurobipy:  10  -3.81813077e-03  4.96093175e-03  1.06e-09 8.35e-10  1.73e-05     0s
# INFO:gurobipy:  11  -5.21480395e-07  1.10515760e-07  6.77e-11 7.69e-12  1.23e-09     0s
# INFO:gurobipy:  12  -5.10398071e-10  1.34777864e-10  1.31e-13 7.44e-13  1.23e-12     0s
# INFO:gurobipy:
# INFO:gurobipy:Barrier solved model in 12 iterations and 0.01 seconds (0.00 work units)
# INFO:gurobipy:Optimal objective -5.10398071e-10
# INFO:gurobipy:
# INFO:linopy.constants: Optimization successful:
# Status: ok
# Termination condition: optimal
# Solution: 296 primals, 689 duals
# Objective: 1.35e-10
# Solver: gurobi
# Runtime: 0.01s
# Dual bound: 1.35e-10
# Solver model: available
# Solver message: 2
#
# INFO:pypsa.optimization.optimize:The shadow-prices of the constraints Generator-ext-p-lower, Generator-ext-p-upper, Line-ext-s-lower, Line-ext-s-upper, StorageUnit-ext-p_dispatch-lower, StorageUnit-ext-p_dispatch-upper, StorageUnit-ext-p_store-lower, StorageUnit-ext-p_store-upper, StorageUnit-ext-state_of_charge-lower, StorageUnit-ext-state_of_charge-upper, StorageUnit-energy_balance, budget were not assigned to the network.

# %% [markdown]
# ### 2.3 Inspect the alternatives

# %%
mga_total_capacities = pd.concat((
    pd.DataFrame(mga_alternatives[x]).fillna(0).round(2).sum(axis=1) for x in mga_alternatives
), axis=1)

mga_spatial_capacities = pd.concat((
    pd.DataFrame(mga_spatial_alternatives[x]).fillna(0).round(2).sum(axis=1) for x in mga_alternatives
), axis=1)

# %%
mga_total_capacities.plot.bar()
# Out:
# <Axes: >

# %%
mga_spatial_capacities.plot.bar()
# Out:
# <Axes: >

# %%
mga_weights = pd.concat((
    pd.DataFrame(mga_weights[x]).fillna(0).round(2).sum(axis=1) for x in mga_weights
), axis=1)
mga_weights
# Out:
#                 0     1     2     3     4     5
# OCGT          0.0  0.06  0.70  0.00  0.84  0.00
# solar_bus1    0.0  0.00  0.00  0.02  0.00  0.02
# wind_bus1     0.0  0.00  0.66  0.00  0.47  0.00
# solar_bus2    0.0  0.00  0.00  0.02  0.00  0.03
# wind_bus2     0.0  0.95  0.00  0.96  0.00  0.96
# battery_bus1  0.0  0.00  0.29  0.00  0.28  0.00
# battery_bus2  0.0  0.31  0.00  0.29  0.00  0.29

# %% [markdown]
# ## 3. Generate alternative solutions with SPORES MGA (diversificaton + intensification)
# This time, we first identify an extreme of the solution space (highest solar capacity while lowest wind capacity), then generate diversity around it. This is achieved via the 'intensification' feature of SPORES.

# %% [markdown]
# ### 3.1 Load and check new MGA configuration

# %%
with open("../../configs/test_config_spores_diversify_intensify.yaml") as yf:
    test_config = SPORESConfig.model_validate(yaml.safe_load(yf))
test_config
# Out:
# {'config_name': 'spores',
#  'model_interface': 'pypsa',
#  'cost_slack': 0.1,
#  'alternatives': 5,
#  'spatially_explicit': True,
#  'diversification_coefficient': 'auto',
#  'intensification_coefficient': [1, -1],
#  'diversified_technologies': ['wind', 'solar', 'gas', 'battery'],
#  'intensified_technologies': ['wind', 'solar']}

# %% [markdown]
# ### 3.2 Run the SPORES algorithm with the new configuration

# %%
mga_alternatives, mga_spatial_alternatives, mga_weights = spores_algorithm(test_config, n)
# Out:
# WARNING:pypsa.consistency:Encountered nan's in varying data 'v_ang' for columns ['bus1', 'bus2'] of component 'Bus'.
# WARNING:pypsa.consistency:The following lines have zero x, which could break the linear load flow:
# Index(['line'], dtype='object', name='name')
# WARNING:pypsa.consistency:The following lines have zero r, which could break the linear load flow:
# Index(['line'], dtype='object', name='name')
# INFO:linopy.model: Solve problem using Gurobi solver
# INFO:linopy.model:Solver options:
#  - Method: 2
#  - Crossover: 0
#  - log_to_console: False
# INFO:linopy.io: Writing time: 0.05s
# Technologies [] not found in the model
# Set parameter Username
# INFO:gurobipy:Set parameter Username
# Academic license - for non-commercial use only - expires 2026-08-25
# INFO:gurobipy:Academic license - for non-commercial use only - expires 2026-08-25
# Read LP format model from file /tmp/linopy-problem-jewbh_3d.lp
# INFO:gurobipy:Read LP format model from file /tmp/linopy-problem-jewbh_3d.lp
# Reading time = 0.00 seconds
# INFO:gurobipy:Reading time = 0.00 seconds
# obj: 689 rows, 296 columns, 1332 nonzeros
# INFO:gurobipy:obj: 689 rows, 296 columns, 1332 nonzeros
# Set parameter Method to value 2
# INFO:gurobipy:Set parameter Method to value 2
# Set parameter Crossover to value 0
# INFO:gurobipy:Set parameter Crossover to value 0
# Set parameter LogToConsole to value 0
# INFO:gurobipy:Set parameter LogToConsole to value 0
# INFO:gurobipy:Gurobi Optimizer version 12.0.3 build v12.0.3rc0 (linux64 - "Linux Mint 22")
# INFO:gurobipy:
# INFO:gurobipy:CPU model: Intel(R) Core(TM) i7-10610U CPU @ 1.80GHz, instruction set [SSE2|AVX|AVX2]
# INFO:gurobipy:Thread count: 4 physical cores, 8 logical processors, using up to 8 threads
# INFO:gurobipy:
# INFO:gurobipy:Non-default parameters:
# INFO:gurobipy:Method  2
# INFO:gurobipy:Crossover  0
# INFO:gurobipy:LogToConsole  0
# INFO:gurobipy:
# INFO:gurobipy:Optimize a model with 689 rows, 296 columns and 1332 nonzeros
# INFO:gurobipy:Model fingerprint: 0xe2c2d338
# INFO:gurobipy:Coefficient statistics:
# INFO:gurobipy:  Matrix range     [4e-02, 2e+03]
# INFO:gurobipy:  Objective range  [5e-01, 5e-01]
# INFO:gurobipy:  Bounds range     [0e+00, 0e+00]
# INFO:gurobipy:  RHS range        [2e+02, 7e+05]
# INFO:gurobipy:Presolve removed 124 rows and 334 columns
# INFO:gurobipy:Presolve time: 0.00s
# INFO:gurobipy:Presolved: 172 rows, 355 columns, 1578 nonzeros
# INFO:gurobipy:Ordering time: 0.00s
# INFO:gurobipy:
# INFO:gurobipy:Barrier statistics:
# INFO:gurobipy: Free vars  : 6
# INFO:gurobipy: AA' NZ     : 1.490e+03
# INFO:gurobipy: Factor NZ  : 3.248e+03
# INFO:gurobipy: Factor Ops : 6.994e+04 (less than 1 second per iteration)
# INFO:gurobipy: Threads    : 1
# INFO:gurobipy:
# INFO:gurobipy:                  Objective                Residual
# INFO:gurobipy:Iter       Primal          Dual         Primal    Dual     Compl     Time
# INFO:gurobipy:   0  -8.42012011e+03 -0.00000000e+00  9.01e-01 2.28e+02  3.21e+02     0s
# INFO:gurobipy:   1  -8.08237157e+03 -1.19183889e+03  3.73e-01 5.57e+02  7.48e+01     0s
# INFO:gurobipy:   2  -5.20528318e+03 -3.31134297e+02  1.30e-01 1.74e+02  2.82e+01     0s
# INFO:gurobipy:   3  -1.14304939e+03  5.27539180e+01  5.69e-03 3.37e+01  5.07e+00     0s
# INFO:gurobipy:   4  -3.96973283e+02  1.61850459e+01  8.75e-04 1.24e+01  1.79e+00     0s
# INFO:gurobipy:   5  -1.86769125e+02 -5.34716617e+01  3.79e-05 5.18e+00  5.80e-01     0s
# INFO:gurobipy:   6  -1.01613292e+02 -5.80660239e+01  2.77e-06 1.79e+00  1.77e-01     0s
# INFO:gurobipy:   7  -8.77043600e+01 -5.89531228e+01  1.41e-06 3.06e-01  7.26e-02     0s
# INFO:gurobipy:   8  -7.76921162e+01 -6.87694540e+01  3.25e-07 7.25e-02  2.13e-02     0s
# INFO:gurobipy:   9  -7.48727719e+01 -7.13096013e+01  1.33e-07 2.19e-02  8.13e-03     0s
# INFO:gurobipy:  10  -7.27810490e+01 -7.20847013e+01  1.07e-08 3.65e-03  1.56e-03     0s
# INFO:gurobipy:  11  -7.25780535e+01 -7.24697124e+01  1.72e-09 4.86e-04  2.38e-04     0s
# INFO:gurobipy:  12  -7.25291683e+01 -7.25260473e+01  1.36e-10 4.21e-06  6.38e-06     0s
# INFO:gurobipy:  13  -7.25277092e+01 -7.25277060e+01  1.90e-12 5.96e-11  6.38e-09     0s
# INFO:gurobipy:  14  -7.25277078e+01 -7.25277078e+01  7.85e-14 1.78e-12  6.38e-12     0s
# INFO:gurobipy:
# INFO:gurobipy:Barrier solved model in 14 iterations and 0.01 seconds (0.00 work units)
# INFO:gurobipy:Optimal objective -7.25277078e+01
# INFO:gurobipy:
# INFO:linopy.constants: Optimization successful:
# Status: ok
# Termination condition: optimal
# Solution: 296 primals, 689 duals
# Objective: -7.25e+01
# Solver: gurobi
# Runtime: 0.02s
# Dual bound: -7.25e+01
# Solver model: available
# Solver message: 2
#
# INFO:pypsa.optimization.optimize:The shadow-prices of the constraints Generator-ext-p-lower, Generator-ext-p-upper, Line-ext-s-lower, Line-ext-s-upper, StorageUnit-ext-p_dispatch-lower, StorageUnit-ext-p_dispatch-upper, StorageUnit-ext-p_store-lower, StorageUnit-ext-p_store-upper, StorageUnit-ext-state_of_charge-lower, StorageUnit-ext-state_of_charge-upper, StorageUnit-energy_balance, budget were not assigned to the network.
# INFO:linopy.model: Solve problem using Gurobi solver
# INFO:linopy.model:Solver options:
#  - Method: 2
#  - Crossover: 0
#  - log_to_console: False
# INFO:linopy.io: Writing time: 0.05s
# Set parameter Username
# INFO:gurobipy:Set parameter Username
# Academic license - for non-commercial use only - expires 2026-08-25
# INFO:gurobipy:Academic license - for non-commercial use only - expires 2026-08-25
# Read LP format model from file /tmp/linopy-problem-nvbak_zm.lp
# INFO:gurobipy:Read LP format model from file /tmp/linopy-problem-nvbak_zm.lp
# Reading time = 0.00 seconds
# INFO:gurobipy:Reading time = 0.00 seconds
# obj: 689 rows, 296 columns, 1332 nonzeros
# INFO:gurobipy:obj: 689 rows, 296 columns, 1332 nonzeros
# Set parameter Method to value 2
# INFO:gurobipy:Set parameter Method to value 2
# Set parameter Crossover to value 0
# INFO:gurobipy:Set parameter Crossover to value 0
# Set parameter LogToConsole to value 0
# INFO:gurobipy:Set parameter LogToConsole to value 0
# INFO:gurobipy:Gurobi Optimizer version 12.0.3 build v12.0.3rc0 (linux64 - "Linux Mint 22")
# INFO:gurobipy:
# INFO:gurobipy:CPU model: Intel(R) Core(TM) i7-10610U CPU @ 1.80GHz, instruction set [SSE2|AVX|AVX2]
# INFO:gurobipy:Thread count: 4 physical cores, 8 logical processors, using up to 8 threads
# INFO:gurobipy:
# INFO:gurobipy:Non-default parameters:
# INFO:gurobipy:Method  2
# INFO:gurobipy:Crossover  0
# INFO:gurobipy:LogToConsole  0
# INFO:gurobipy:
# INFO:gurobipy:Optimize a model with 689 rows, 296 columns and 1332 nonzeros
# INFO:gurobipy:Model fingerprint: 0x3a886d2d
# INFO:gurobipy:Coefficient statistics:
# INFO:gurobipy:  Matrix range     [4e-02, 2e+03]
# INFO:gurobipy:  Objective range  [3e-12, 5e-01]
# INFO:gurobipy:  Bounds range     [0e+00, 0e+00]
# INFO:gurobipy:  RHS range        [2e+02, 7e+05]
# INFO:gurobipy:Presolve removed 124 rows and 334 columns
# INFO:gurobipy:Presolve time: 0.00s
# INFO:gurobipy:Presolved: 172 rows, 355 columns, 1578 nonzeros
# INFO:gurobipy:Ordering time: 0.00s
# INFO:gurobipy:
# INFO:gurobipy:Barrier statistics:
# INFO:gurobipy: Free vars  : 6
# INFO:gurobipy: AA' NZ     : 1.490e+03
# INFO:gurobipy: Factor NZ  : 3.248e+03
# INFO:gurobipy: Factor Ops : 6.994e+04 (less than 1 second per iteration)
# INFO:gurobipy: Threads    : 1
# INFO:gurobipy:
# INFO:gurobipy:                  Objective                Residual
# INFO:gurobipy:Iter       Primal          Dual         Primal    Dual     Compl     Time
# INFO:gurobipy:   0  -8.36216446e+03 -0.00000000e+00  9.01e-01 2.28e+02  3.20e+02     0s
# INFO:gurobipy:   1  -7.96952764e+03 -8.82207524e+02  3.38e-01 5.72e+02  7.54e+01     0s
# INFO:gurobipy:   2  -4.78585269e+03 -1.21590809e+02  9.37e-02 1.63e+02  2.57e+01     0s
# INFO:gurobipy:   3  -1.01312313e+03  1.74423569e+02  4.73e-03 2.79e+01  4.36e+00     0s
# INFO:gurobipy:   4  -2.61298671e+02  1.55102888e+02  8.08e-04 1.17e+01  1.64e+00     0s
# INFO:gurobipy:   5  -6.60846163e+01  8.60057023e+01  3.35e-05 5.55e+00  5.98e-01     0s
# INFO:gurobipy:   6   3.55896842e+00  6.08769275e+01  1.70e-06 1.61e+00  1.85e-01     0s
# INFO:gurobipy:   7   7.26723387e+00  4.80837187e+01  1.16e-06 8.75e-01  1.22e-01     0s
# INFO:gurobipy:   8   1.96995974e+01  4.40649234e+01  4.39e-07 6.20e-01  7.89e-02     0s
# INFO:gurobipy:   9   2.27026257e+01  3.80412695e+01  3.04e-07 3.39e-01  4.71e-02     0s
# INFO:gurobipy:  10   2.83370491e+01  3.37728385e+01  8.65e-08 1.01e-01  1.58e-02     0s
# INFO:gurobipy:  11   3.08601418e+01  3.27051266e+01  2.22e-08 4.29e-02  5.83e-03     0s
# INFO:gurobipy:  12   3.18092946e+01  3.20428205e+01  4.03e-09 2.41e-03  5.86e-04     0s
# INFO:gurobipy:  13   3.19352434e+01  3.19467129e+01  2.49e-10 3.48e-06  2.27e-05     0s
# INFO:gurobipy:  14   3.19400314e+01  3.19400431e+01  1.55e-11 2.86e-10  2.28e-08     0s
# INFO:gurobipy:  15   3.19400362e+01  3.19400362e+01  1.18e-13 3.19e-12  2.04e-13     0s
# INFO:gurobipy:
# INFO:gurobipy:Barrier solved model in 15 iterations and 0.02 seconds (0.00 work units)
# INFO:gurobipy:Optimal objective 3.19400362e+01
# INFO:gurobipy:
# INFO:linopy.constants: Optimization successful:
# Status: ok
# Termination condition: optimal
# Solution: 296 primals, 689 duals
# Objective: 3.19e+01
# Solver: gurobi
# Runtime: 0.02s
# Dual bound: 3.19e+01
# Solver model: available
# Solver message: 2
#
# INFO:pypsa.optimization.optimize:The shadow-prices of the constraints Generator-ext-p-lower, Generator-ext-p-upper, Line-ext-s-lower, Line-ext-s-upper, StorageUnit-ext-p_dispatch-lower, StorageUnit-ext-p_dispatch-upper, StorageUnit-ext-p_store-lower, StorageUnit-ext-p_store-upper, StorageUnit-ext-state_of_charge-lower, StorageUnit-ext-state_of_charge-upper, StorageUnit-energy_balance, budget were not assigned to the network.
# INFO:linopy.model: Solve problem using Gurobi solver
# INFO:linopy.model:Solver options:
#  - Method: 2
#  - Crossover: 0
#  - log_to_console: False
# INFO:linopy.io: Writing time: 0.07s
# Set parameter Username
# INFO:gurobipy:Set parameter Username
# Academic license - for non-commercial use only - expires 2026-08-25
# INFO:gurobipy:Academic license - for non-commercial use only - expires 2026-08-25
# Read LP format model from file /tmp/linopy-problem-yc_ecaff.lp
# INFO:gurobipy:Read LP format model from file /tmp/linopy-problem-yc_ecaff.lp
# Reading time = 0.00 seconds
# INFO:gurobipy:Reading time = 0.00 seconds
# obj: 689 rows, 296 columns, 1332 nonzeros
# INFO:gurobipy:obj: 689 rows, 296 columns, 1332 nonzeros
# Set parameter Method to value 2
# INFO:gurobipy:Set parameter Method to value 2
# Set parameter Crossover to value 0
# INFO:gurobipy:Set parameter Crossover to value 0
# Set parameter LogToConsole to value 0
# INFO:gurobipy:Set parameter LogToConsole to value 0
# INFO:gurobipy:Gurobi Optimizer version 12.0.3 build v12.0.3rc0 (linux64 - "Linux Mint 22")
# INFO:gurobipy:
# INFO:gurobipy:CPU model: Intel(R) Core(TM) i7-10610U CPU @ 1.80GHz, instruction set [SSE2|AVX|AVX2]
# INFO:gurobipy:Thread count: 4 physical cores, 8 logical processors, using up to 8 threads
# INFO:gurobipy:
# INFO:gurobipy:Non-default parameters:
# INFO:gurobipy:Method  2
# INFO:gurobipy:Crossover  0
# INFO:gurobipy:LogToConsole  0
# INFO:gurobipy:
# INFO:gurobipy:Optimize a model with 689 rows, 296 columns and 1332 nonzeros
# INFO:gurobipy:Model fingerprint: 0x09c03c3d
# INFO:gurobipy:Coefficient statistics:
# INFO:gurobipy:  Matrix range     [4e-02, 2e+03]
# INFO:gurobipy:  Objective range  [4e-14, 5e-01]
# INFO:gurobipy:  Bounds range     [0e+00, 0e+00]
# INFO:gurobipy:  RHS range        [2e+02, 7e+05]
# INFO:gurobipy:Presolve removed 124 rows and 334 columns
# INFO:gurobipy:Presolve time: 0.00s
# INFO:gurobipy:Presolved: 172 rows, 355 columns, 1578 nonzeros
# INFO:gurobipy:Ordering time: 0.00s
# INFO:gurobipy:
# INFO:gurobipy:Barrier statistics:
# INFO:gurobipy: Free vars  : 6
# INFO:gurobipy: AA' NZ     : 1.490e+03
# INFO:gurobipy: Factor NZ  : 3.248e+03
# INFO:gurobipy: Factor Ops : 6.994e+04 (less than 1 second per iteration)
# INFO:gurobipy: Threads    : 1
# INFO:gurobipy:
# INFO:gurobipy:                  Objective                Residual
# INFO:gurobipy:Iter       Primal          Dual         Primal    Dual     Compl     Time
# INFO:gurobipy:   0  -8.36704188e+03 -0.00000000e+00  9.01e-01 2.28e+02  3.20e+02     0s
# INFO:gurobipy:   1  -7.97963346e+03 -8.95456242e+02  3.43e-01 5.71e+02  7.54e+01     0s
# INFO:gurobipy:   2  -4.82446676e+03 -1.54981689e+02  9.38e-02 1.58e+02  2.54e+01     0s
# INFO:gurobipy:   3  -1.00134662e+03  3.07099621e+01  5.03e-03 3.09e+01  4.43e+00     0s
# INFO:gurobipy:   4  -2.77383902e+02  4.11890967e+01  1.20e-03 1.36e+01  1.73e+00     0s
# INFO:gurobipy:   5  -1.03065038e+02  1.47148379e+01  1.14e-04 6.04e+00  6.35e-01     0s
# INFO:gurobipy:   6  -1.99193658e+01  2.62740004e+01  1.01e-05 1.72e+00  1.88e-01     0s
# INFO:gurobipy:   7  -4.24841537e+00  2.38358298e+01  4.05e-06 3.79e-01  7.76e-02     0s
# INFO:gurobipy:   8   6.10303701e+00  1.38948875e+01  6.05e-07 6.32e-02  1.91e-02     0s
# INFO:gurobipy:   9   9.54167547e+00  1.16959032e+01  9.85e-08 2.16e-02  5.56e-03     0s
# INFO:gurobipy:  10   1.04662194e+01  1.07833970e+01  1.10e-08 1.66e-03  7.28e-04     0s
# INFO:gurobipy:  11   1.06200588e+01  1.06633950e+01  1.17e-09 1.75e-04  9.64e-05     0s
# INFO:gurobipy:  12   1.06416285e+01  1.06416789e+01  2.49e-11 9.33e-10  9.80e-08     0s
# INFO:gurobipy:  13   1.06416505e+01  1.06416506e+01  9.61e-14 1.82e-12  9.80e-11     0s
# INFO:gurobipy:
# INFO:gurobipy:Barrier solved model in 13 iterations and 0.02 seconds (0.00 work units)
# INFO:gurobipy:Optimal objective 1.06416505e+01
# INFO:gurobipy:
# INFO:linopy.constants: Optimization successful:
# Status: ok
# Termination condition: optimal
# Solution: 296 primals, 689 duals
# Objective: 1.06e+01
# Solver: gurobi
# Runtime: 0.02s
# Dual bound: 1.06e+01
# Solver model: available
# Solver message: 2
#
# INFO:pypsa.optimization.optimize:The shadow-prices of the constraints Generator-ext-p-lower, Generator-ext-p-upper, Line-ext-s-lower, Line-ext-s-upper, StorageUnit-ext-p_dispatch-lower, StorageUnit-ext-p_dispatch-upper, StorageUnit-ext-p_store-lower, StorageUnit-ext-p_store-upper, StorageUnit-ext-state_of_charge-lower, StorageUnit-ext-state_of_charge-upper, StorageUnit-energy_balance, budget were not assigned to the network.
# INFO:linopy.model: Solve problem using Gurobi solver
# INFO:linopy.model:Solver options:
#  - Method: 2
#  - Crossover: 0
#  - log_to_console: False
# INFO:linopy.io: Writing time: 0.09s
# Set parameter Username
# INFO:gurobipy:Set parameter Username
# Academic license - for non-commercial use only - expires 2026-08-25
# INFO:gurobipy:Academic license - for non-commercial use only - expires 2026-08-25
# Read LP format model from file /tmp/linopy-problem-wvlqc3y0.lp
# INFO:gurobipy:Read LP format model from file /tmp/linopy-problem-wvlqc3y0.lp
# Reading time = 0.00 seconds
# INFO:gurobipy:Reading time = 0.00 seconds
# obj: 689 rows, 296 columns, 1332 nonzeros
# INFO:gurobipy:obj: 689 rows, 296 columns, 1332 nonzeros
# Set parameter Method to value 2
# INFO:gurobipy:Set parameter Method to value 2
# Set parameter Crossover to value 0
# INFO:gurobipy:Set parameter Crossover to value 0
# Set parameter LogToConsole to value 0
# INFO:gurobipy:Set parameter LogToConsole to value 0
# INFO:gurobipy:Gurobi Optimizer version 12.0.3 build v12.0.3rc0 (linux64 - "Linux Mint 22")
# INFO:gurobipy:
# INFO:gurobipy:CPU model: Intel(R) Core(TM) i7-10610U CPU @ 1.80GHz, instruction set [SSE2|AVX|AVX2]
# INFO:gurobipy:Thread count: 4 physical cores, 8 logical processors, using up to 8 threads
# INFO:gurobipy:
# INFO:gurobipy:Non-default parameters:
# INFO:gurobipy:Method  2
# INFO:gurobipy:Crossover  0
# INFO:gurobipy:LogToConsole  0
# INFO:gurobipy:
# INFO:gurobipy:Optimize a model with 689 rows, 296 columns and 1332 nonzeros
# INFO:gurobipy:Model fingerprint: 0x8a450876
# INFO:gurobipy:Coefficient statistics:
# INFO:gurobipy:  Matrix range     [4e-02, 2e+03]
# INFO:gurobipy:  Objective range  [5e-11, 5e-01]
# INFO:gurobipy:  Bounds range     [0e+00, 0e+00]
# INFO:gurobipy:  RHS range        [2e+02, 7e+05]
# INFO:gurobipy:Presolve removed 124 rows and 334 columns
# INFO:gurobipy:Presolve time: 0.00s
# INFO:gurobipy:Presolved: 172 rows, 355 columns, 1578 nonzeros
# INFO:gurobipy:Ordering time: 0.00s
# INFO:gurobipy:
# INFO:gurobipy:Barrier statistics:
# INFO:gurobipy: Free vars  : 6
# INFO:gurobipy: AA' NZ     : 1.490e+03
# INFO:gurobipy: Factor NZ  : 3.248e+03
# INFO:gurobipy: Factor Ops : 6.994e+04 (less than 1 second per iteration)
# INFO:gurobipy: Threads    : 1
# INFO:gurobipy:
# INFO:gurobipy:                  Objective                Residual
# INFO:gurobipy:Iter       Primal          Dual         Primal    Dual     Compl     Time
# INFO:gurobipy:   0  -8.36710746e+03 -0.00000000e+00  9.01e-01 2.28e+02  3.20e+02     0s
# INFO:gurobipy:   1  -7.98016214e+03 -8.94795515e+02  3.43e-01 5.71e+02  7.54e+01     0s
# INFO:gurobipy:   2  -4.83781103e+03 -1.60336425e+02  9.62e-02 1.60e+02  2.57e+01     0s
# INFO:gurobipy:   3  -1.06875099e+03  1.12758206e+02  5.09e-03 3.08e+01  4.64e+00     0s
# INFO:gurobipy:   4  -3.10739488e+02  1.18039076e+02  1.18e-03 1.30e+01  1.82e+00     0s
# INFO:gurobipy:   5  -9.98908908e+01  6.74045241e+01  1.23e-04 5.93e+00  6.85e-01     0s
# INFO:gurobipy:   6  -2.78216726e+01  4.07823454e+01  1.07e-05 1.67e+00  2.25e-01     0s
# INFO:gurobipy:   7  -1.78358257e+01  3.26402848e+01  8.17e-06 3.97e-01  1.23e-01     0s
# INFO:gurobipy:   8  -1.55280423e+00  2.39139540e+01  2.52e-06 1.78e-01  5.99e-02     0s
# INFO:gurobipy:   9   1.97725955e+00  2.04265635e+01  1.81e-06 1.09e-01  4.24e-02     0s
# INFO:gurobipy:  10   6.87178852e+00  1.37429408e+01  6.47e-07 3.09e-02  1.53e-02     0s
# INFO:gurobipy:  11   9.67163136e+00  1.16456140e+01  1.11e-07 1.09e-02  4.56e-03     0s
# INFO:gurobipy:  12   1.05320536e+01  1.08416761e+01  8.61e-09 1.03e-03  6.77e-04     0s
# INFO:gurobipy:  13   1.06351005e+01  1.06490101e+01  2.16e-10 9.61e-09  2.71e-05     0s
# INFO:gurobipy:  14   1.06416439e+01  1.06416580e+01  1.04e-11 3.67e-10  2.73e-08     0s
# INFO:gurobipy:  15   1.06416505e+01  1.06416505e+01  1.41e-13 3.64e-12  4.31e-14     0s
# INFO:gurobipy:
# INFO:gurobipy:Barrier solved model in 15 iterations and 0.02 seconds (0.00 work units)
# INFO:gurobipy:Optimal objective 1.06416505e+01
# INFO:gurobipy:
# INFO:linopy.constants: Optimization successful:
# Status: ok
# Termination condition: optimal
# Solution: 296 primals, 689 duals
# Objective: 1.06e+01
# Solver: gurobi
# Runtime: 0.02s
# Dual bound: 1.06e+01
# Solver model: available
# Solver message: 2
#
# INFO:pypsa.optimization.optimize:The shadow-prices of the constraints Generator-ext-p-lower, Generator-ext-p-upper, Line-ext-s-lower, Line-ext-s-upper, StorageUnit-ext-p_dispatch-lower, StorageUnit-ext-p_dispatch-upper, StorageUnit-ext-p_store-lower, StorageUnit-ext-p_store-upper, StorageUnit-ext-state_of_charge-lower, StorageUnit-ext-state_of_charge-upper, StorageUnit-energy_balance, budget were not assigned to the network.
# INFO:linopy.model: Solve problem using Gurobi solver
# INFO:linopy.model:Solver options:
#  - Method: 2
#  - Crossover: 0
#  - log_to_console: False
# INFO:linopy.io: Writing time: 0.05s
# Set parameter Username
# INFO:gurobipy:Set parameter Username
# Academic license - for non-commercial use only - expires 2026-08-25
# INFO:gurobipy:Academic license - for non-commercial use only - expires 2026-08-25
# Read LP format model from file /tmp/linopy-problem-fmli3hze.lp
# INFO:gurobipy:Read LP format model from file /tmp/linopy-problem-fmli3hze.lp
# Reading time = 0.00 seconds
# INFO:gurobipy:Reading time = 0.00 seconds
# obj: 689 rows, 296 columns, 1332 nonzeros
# INFO:gurobipy:obj: 689 rows, 296 columns, 1332 nonzeros
# Set parameter Method to value 2
# INFO:gurobipy:Set parameter Method to value 2
# Set parameter Crossover to value 0
# INFO:gurobipy:Set parameter Crossover to value 0
# Set parameter LogToConsole to value 0
# INFO:gurobipy:Set parameter LogToConsole to value 0
# INFO:gurobipy:Gurobi Optimizer version 12.0.3 build v12.0.3rc0 (linux64 - "Linux Mint 22")
# INFO:gurobipy:
# INFO:gurobipy:CPU model: Intel(R) Core(TM) i7-10610U CPU @ 1.80GHz, instruction set [SSE2|AVX|AVX2]
# INFO:gurobipy:Thread count: 4 physical cores, 8 logical processors, using up to 8 threads
# INFO:gurobipy:
# INFO:gurobipy:Non-default parameters:
# INFO:gurobipy:Method  2
# INFO:gurobipy:Crossover  0
# INFO:gurobipy:LogToConsole  0
# INFO:gurobipy:
# INFO:gurobipy:Optimize a model with 689 rows, 296 columns and 1332 nonzeros
# INFO:gurobipy:Model fingerprint: 0x7a53fa7d
# INFO:gurobipy:Coefficient statistics:
# INFO:gurobipy:  Matrix range     [4e-02, 2e+03]
# INFO:gurobipy:  Objective range  [2e-14, 5e-01]
# INFO:gurobipy:  Bounds range     [0e+00, 0e+00]
# INFO:gurobipy:  RHS range        [2e+02, 7e+05]
# INFO:gurobipy:Presolve removed 124 rows and 334 columns
# INFO:gurobipy:Presolve time: 0.00s
# INFO:gurobipy:Presolved: 172 rows, 355 columns, 1578 nonzeros
# INFO:gurobipy:Ordering time: 0.00s
# INFO:gurobipy:
# INFO:gurobipy:Barrier statistics:
# INFO:gurobipy: Free vars  : 6
# INFO:gurobipy: AA' NZ     : 1.490e+03
# INFO:gurobipy: Factor NZ  : 3.248e+03
# INFO:gurobipy: Factor Ops : 6.994e+04 (less than 1 second per iteration)
# INFO:gurobipy: Threads    : 1
# INFO:gurobipy:
# INFO:gurobipy:                  Objective                Residual
# INFO:gurobipy:Iter       Primal          Dual         Primal    Dual     Compl     Time
# INFO:gurobipy:   0  -8.36704188e+03 -0.00000000e+00  9.01e-01 2.28e+02  3.20e+02     0s
# INFO:gurobipy:   1  -7.97963346e+03 -8.95456242e+02  3.43e-01 5.71e+02  7.54e+01     0s
# INFO:gurobipy:   2  -4.82446675e+03 -1.54981689e+02  9.38e-02 1.58e+02  2.54e+01     0s
# INFO:gurobipy:   3  -1.00134677e+03  3.07099505e+01  5.03e-03 3.09e+01  4.43e+00     0s
# INFO:gurobipy:   4  -2.77383931e+02  4.11891097e+01  1.20e-03 1.36e+01  1.73e+00     0s
# INFO:gurobipy:   5  -1.03065091e+02  1.47148503e+01  1.14e-04 6.04e+00  6.35e-01     0s
# INFO:gurobipy:   6  -1.99193695e+01  2.62739948e+01  1.01e-05 1.72e+00  1.88e-01     0s
# INFO:gurobipy:   7  -4.24841592e+00  2.38358428e+01  4.05e-06 3.79e-01  7.76e-02     0s
# INFO:gurobipy:   8   6.10304288e+00  1.38948884e+01  6.05e-07 6.32e-02  1.91e-02     0s
# INFO:gurobipy:   9   9.54167753e+00  1.16959036e+01  9.85e-08 2.16e-02  5.56e-03     0s
# INFO:gurobipy:  10   1.04662195e+01  1.07833967e+01  1.10e-08 1.66e-03  7.28e-04     0s
# INFO:gurobipy:  11   1.06200590e+01  1.06633952e+01  1.17e-09 1.75e-04  9.64e-05     0s
# INFO:gurobipy:  12   1.06416285e+01  1.06416789e+01  3.38e-11 9.33e-10  9.80e-08     0s
# INFO:gurobipy:  13   1.06416505e+01  1.06416506e+01  6.41e-14 1.82e-12  9.80e-11     0s
# INFO:gurobipy:
# INFO:gurobipy:Barrier solved model in 13 iterations and 0.01 seconds (0.00 work units)
# INFO:gurobipy:Optimal objective 1.06416505e+01
# INFO:gurobipy:
# INFO:linopy.constants: Optimization successful:
# Status: ok
# Termination condition: optimal
# Solution: 296 primals, 689 duals
# Objective: 1.06e+01
# Solver: gurobi
# Runtime: 0.01s
# Dual bound: 1.06e+01
# Solver model: available
# Solver message: 2
#
# INFO:pypsa.optimization.optimize:The shadow-prices of the constraints Generator-ext-p-lower, Generator-ext-p-upper, Line-ext-s-lower, Line-ext-s-upper, StorageUnit-ext-p_dispatch-lower, StorageUnit-ext-p_dispatch-upper, StorageUnit-ext-p_store-lower, StorageUnit-ext-p_store-upper, StorageUnit-ext-state_of_charge-lower, StorageUnit-ext-state_of_charge-upper, StorageUnit-energy_balance, budget were not assigned to the network.

# %% [markdown]
# ### 3.3 Inspect the new alternatives

# %%
mga_total_capacities = pd.concat((
    pd.DataFrame(mga_alternatives[x]).fillna(0).round(2).sum(axis=1) for x in mga_alternatives
), axis=1)

mga_spatial_capacities = pd.concat((
    pd.DataFrame(mga_spatial_alternatives[x]).fillna(0).round(2).sum(axis=1) for x in mga_alternatives
), axis=1)

# %%
mga_total_capacities.plot.bar()
# Out:
# <Axes: >

# %%
mga_spatial_capacities.plot.bar()
# Out:
# <Axes: >

# %%
mga_weights = pd.concat((
    pd.DataFrame(mga_weights[x]).fillna(0).round(2).sum(axis=1) for x in mga_weights
), axis=1)
mga_weights
# Out:
#                 0    1     2     3     4     5
# OCGT          0.0  0.0  0.45  0.41  0.41  0.41
# solar_bus1    0.0 -0.5 -0.42 -0.21 -0.51 -0.21
# wind_bus1     0.0  0.5  0.52  0.51  0.51  0.51
# solar_bus2    0.0 -0.5 -0.29 -0.51 -0.21 -0.51
# wind_bus2     0.0  0.5  0.52  0.51  0.51  0.51
# battery_bus1  0.0  0.0  0.00  0.00  0.00  0.00
# battery_bus2  0.0  0.0  0.06  0.05  0.05  0.05
